# %%
import tensorflow as tf

def myregression():
    # 1、准备数据，x 特征值 [100, 1]   （100个样本，1个特征）
    x = tf.random_normal([100, 1], mean=1.75, stddev=0.5, name="x_data")
    y_true = tf.matmul(x, [[0.7]]) + 0.8

    # weight也是一个op
    weight = tf.Variable(tf.random_normal([1, 1], mean=0.0, stddev=1.0), name="weight", trainable=True)
    bias = tf.Variable(0.0, name="b")    # 初始化为0.0

    y_predict = tf.matmul(x, weight) + bias

    loss = tf.reduce_mean(tf.square(y_true - y_predict))

    train_op = tf.train.GradientDescentOptimizer(0.1).minimize(loss)

    initializer_op = tf.global_variables_initializer()  # 初始化变量weight和bias

    with tf.Session() as sess:
        sess.run(initializer_op)
        print("随机初始化的参数权重为: %f, 偏置为: %f" % (weight.eval(), bias.eval()))

        filewriter = tf.summary.FileWriter("F:/TensorFlow/logs", graph=sess.graph)
       # 循环训练
        for i in range(500):
            sess.run(train_op)
            print("第%d次优化的参数权重为: %f, 偏置为: %f" % (i, weight.eval(), bias.eval()))

    return None

if __name__ == "__main__":
    myregression()
# Out:
# 随机初始化的参数权重为: -0.025060, 偏置为: 0.000000
# 第0次优化的参数权重为: 0.764033, 偏置为: 0.419008
# 第1次优化的参数权重为: 0.856658, 偏置为: 0.472322
# 第2次优化的参数权重为: 0.871040, 偏置为: 0.485672
# 第3次优化的参数权重为: 0.861100, 偏置为: 0.486488
# 第4次优化的参数权重为: 0.864966, 偏置为: 0.492065
# 第5次优化的参数权重为: 0.870961, 偏置为: 0.499551
# 第6次优化的参数权重为: 0.865576, 偏置为: 0.501158
# 第7次优化的参数权重为: 0.857935, 偏置为: 0.501892
# 第8次优化的参数权重为: 0.857630, 偏置为: 0.505860
# 第9次优化的参数权重为: 0.853741, 偏置为: 0.506788
# 第10次优化的参数权重为: 0.853691, 偏置为: 0.510610
# 第11次优化的参数权重为: 0.855303, 偏置为: 0.516571
# 第12次优化的参数权重为: 0.851586, 偏置为: 0.517635
# 第13次优化的参数权重为: 0.850357, 偏置为: 0.521120
# 第14次优化的参数权重为: 0.854350, 偏置为: 0.527565
# 第15次优化的参数权重为: 0.846273, 偏置为: 0.526502
# 第16次优化的参数权重为: 0.845348, 偏置为: 0.529600
# 第17次优化的参数权重为: 0.848168, 偏置为: 0.534935
# 第18次优化的参数权重为: 0.844236, 偏置为: 0.537539
# 第19次优化的参数权重为: 0.843582, 偏置为: 0.540881
# 第20次优化的参数权重为: 0.835733, 偏置为: 0.540453
# 第21次优化的参数权重为: 0.838840, 偏置为: 0.545748
# 第22次优化的参数权重为: 0.839746, 偏置为: 0.550009
# 第23次优化的参数权重为: 0.834228, 偏置为: 0.551456
# 第24次优化的参数权重为: 0.834150, 偏置为: 0.555627
# 第25次优化的参数权重为: 0.831612, 偏置为: 0.558061
# 第26次优化的参数权重为: 0.829698, 偏置为: 0.560564
# 第27次优化的参数权重为: 0.829019, 偏置为: 0.563304
# 第28次优化的参数权重为: 0.826824, 偏置为: 0.565931
# 第29次优化的参数权重为: 0.824742, 偏置为: 0.568499
# 第30次优化的参数权重为: 0.824558, 偏置为: 0.572129
# 第31次优化的参数权重为: 0.823160, 偏置为: 0.575567
# 第32次优化的参数权重为: 0.817369, 偏置为: 0.575868
# 第33次优化的参数权重为: 0.819610, 偏置为: 0.581032
# 第34次优化的参数权重为: 0.814454, 偏置为: 0.582332
# 第35次优化的参数权重为: 0.817708, 偏置为: 0.588039
# 第36次优化的参数权重为: 0.813780, 偏置为: 0.589118
# 第37次优化的参数权重为: 0.811516, 偏置为: 0.590837
# 第38次优化的参数权重为: 0.811723, 偏置为: 0.594276
# 第39次优化的参数权重为: 0.807565, 偏置为: 0.594965
# 第40次优化的参数权重为: 0.806295, 偏置为: 0.596720
# 第41次优化的参数权重为: 0.807706, 偏置为: 0.600745
# 第42次优化的参数权重为: 0.804695, 偏置为: 0.601684
# 第43次优化的参数权重为: 0.800825, 偏置为: 0.602333
# 第44次优化的参数权重为: 0.801589, 偏置为: 0.605880
# 第45次优化的参数权重为: 0.801647, 偏置为: 0.609837
# 第46次优化的参数权重为: 0.803086, 偏置为: 0.612996
# 第47次优化的参数权重为: 0.800528, 偏置为: 0.614531
# 第48次优化的参数权重为: 0.797935, 偏置为: 0.615942
# 第49次优化的参数权重为: 0.797038, 偏置为: 0.618425
# 第50次优化的参数权重为: 0.794513, 偏置为: 0.619782
# 第51次优化的参数权重为: 0.793071, 偏置为: 0.622321
# 第52次优化的参数权重为: 0.794279, 偏置为: 0.625562
# 第53次优化的参数权重为: 0.792802, 偏置为: 0.627656
# 第54次优化的参数权重为: 0.787930, 偏置为: 0.627478
# 第55次优化的参数权重为: 0.789654, 偏置为: 0.630801
# 第56次优化的参数权重为: 0.790825, 偏置为: 0.633846
# 第57次优化的参数权重为: 0.788729, 偏置为: 0.635580
# 第58次优化的参数权重为: 0.788140, 偏置为: 0.637815
# 第59次优化的参数权重为: 0.783238, 偏置为: 0.637823
# 第60次优化的参数权重为: 0.784442, 偏置为: 0.640837
# 第61次优化的参数权重为: 0.786000, 偏置为: 0.644362
# 第62次优化的参数权重为: 0.784015, 偏置为: 0.645360
# 第63次优化的参数权重为: 0.781755, 偏置为: 0.646209
# 第64次优化的参数权重为: 0.780653, 偏置为: 0.648170
# 第65次优化的参数权重为: 0.781560, 偏置为: 0.651267
# 第66次优化的参数权重为: 0.779205, 偏置为: 0.652167
# 第67次优化的参数权重为: 0.776750, 偏置为: 0.653128
# 第68次优化的参数权重为: 0.777915, 偏置为: 0.655513
# 第69次优化的参数权重为: 0.777553, 偏置为: 0.657654
# 第70次优化的参数权重为: 0.776264, 偏置为: 0.658852
# 第71次优化的参数权重为: 0.776545, 偏置为: 0.660847
# 第72次优化的参数权重为: 0.773656, 偏置为: 0.661340
# 第73次优化的参数权重为: 0.773914, 偏置为: 0.663469
# 第74次优化的参数权重为: 0.772162, 偏置为: 0.664224
# 第75次优化的参数权重为: 0.770368, 偏置为: 0.665547
# 第76次优化的参数权重为: 0.771310, 偏置为: 0.668023
# 第77次优化的参数权重为: 0.766409, 偏置为: 0.667878
# 第78次优化的参数权重为: 0.766716, 偏置为: 0.669937
# 第79次优化的参数权重为: 0.766677, 偏置为: 0.671767
# 第80次优化的参数权重为: 0.766445, 偏置为: 0.673676
# 第81次优化的参数权重为: 0.764638, 偏置为: 0.674740
# 第82次优化的参数权重为: 0.766761, 偏置为: 0.677907
# 第83次优化的参数权重为: 0.764972, 偏置为: 0.678601
# 第84次优化的参数权重为: 0.764961, 偏置为: 0.680582
# 第85次优化的参数权重为: 0.763992, 偏置为: 0.682546
# 第86次优化的参数权重为: 0.764079, 偏置为: 0.684052
# 第87次优化的参数权重为: 0.763694, 偏置为: 0.685203
# 第88次优化的参数权重为: 0.761020, 偏置为: 0.685519
# 第89次优化的参数权重为: 0.758973, 偏置为: 0.686191
# 第90次优化的参数权重为: 0.761128, 偏置为: 0.689372
# 第91次优化的参数权重为: 0.756962, 偏置为: 0.688850
# 第92次优化的参数权重为: 0.757538, 偏置为: 0.690975
# 第93次优化的参数权重为: 0.756554, 偏置为: 0.692379
# 第94次优化的参数权重为: 0.755634, 偏置为: 0.693770
# 第95次优化的参数权重为: 0.755791, 偏置为: 0.695669
# 第96次优化的参数权重为: 0.756376, 偏置为: 0.697610
# 第97次优化的参数权重为: 0.753784, 偏置为: 0.697794
# 第98次优化的参数权重为: 0.752953, 偏置为: 0.698947
# 第99次优化的参数权重为: 0.753458, 偏置为: 0.700516
# 第100次优化的参数权重为: 0.752109, 偏置为: 0.701006
# 第101次优化的参数权重为: 0.751304, 偏置为: 0.701883
# 第102次优化的参数权重为: 0.750992, 偏置为: 0.703166
# 第103次优化的参数权重为: 0.751848, 偏置为: 0.704945
# 第104次优化的参数权重为: 0.750787, 偏置为: 0.705921
# 第105次优化的参数权重为: 0.750619, 偏置为: 0.707199
# 第106次优化的参数权重为: 0.750116, 偏置为: 0.708645
# 第107次优化的参数权重为: 0.749258, 偏置为: 0.709824
# 第108次优化的参数权重为: 0.747873, 偏置为: 0.710318
# 第109次优化的参数权重为: 0.747216, 偏置为: 0.711390
# 第110次优化的参数权重为: 0.746578, 偏置为: 0.712196
# 第111次优化的参数权重为: 0.744979, 偏置为: 0.712738
# 第112次优化的参数权重为: 0.745361, 偏置为: 0.714294
# 第113次优化的参数权重为: 0.745303, 偏置为: 0.715251
# 第114次优化的参数权重为: 0.744881, 偏置为: 0.715994
# 第115次优化的参数权重为: 0.744766, 偏置为: 0.717098
# 第116次优化的参数权重为: 0.744165, 偏置为: 0.717974
# 第117次优化的参数权重为: 0.743824, 偏置为: 0.718726
# 第118次优化的参数权重为: 0.742554, 偏置为: 0.719348
# 第119次优化的参数权重为: 0.742360, 偏置为: 0.720427
# 第120次优化的参数权重为: 0.742640, 偏置为: 0.721862
# 第121次优化的参数权重为: 0.742561, 偏置为: 0.723018
# 第122次优化的参数权重为: 0.742076, 偏置为: 0.723986
# 第123次优化的参数权重为: 0.740402, 偏置为: 0.724194
# 第124次优化的参数权重为: 0.739391, 偏置为: 0.724705
# 第125次优化的参数权重为: 0.739919, 偏置为: 0.725963
# 第126次优化的参数权重为: 0.739073, 偏置为: 0.727021
# 第127次优化的参数权重为: 0.738368, 偏置为: 0.727614
# 第128次优化的参数权重为: 0.738466, 偏置为: 0.728569
# 第129次优化的参数权重为: 0.738534, 偏置为: 0.729387
# 第130次优化的参数权重为: 0.737876, 偏置为: 0.730034
# 第131次优化的参数权重为: 0.737550, 偏置为: 0.730917
# 第132次优化的参数权重为: 0.737042, 偏置为: 0.731673
# 第133次优化的参数权重为: 0.735999, 偏置为: 0.732102
# 第134次优化的参数权重为: 0.736345, 偏置为: 0.733550
# 第135次优化的参数权重为: 0.736123, 偏置为: 0.734354
# 第136次优化的参数权重为: 0.735208, 偏置为: 0.735044
# 第137次优化的参数权重为: 0.735597, 偏置为: 0.736403
# 第138次优化的参数权重为: 0.734002, 偏置为: 0.736452
# 第139次优化的参数权重为: 0.733419, 偏置为: 0.737053
# 第140次优化的参数权重为: 0.733711, 偏置为: 0.738199
# 第141次优化的参数权重为: 0.733591, 偏置为: 0.738886
# 第142次优化的参数权重为: 0.732848, 偏置为: 0.739485
# 第143次优化的参数权重为: 0.732503, 偏置为: 0.740491
# 第144次优化的参数权重为: 0.731760, 偏置为: 0.740945
# 第145次优化的参数权重为: 0.731104, 偏置为: 0.741704
# 第146次优化的参数权重为: 0.730828, 偏置为: 0.742577
# 第147次优化的参数权重为: 0.730863, 偏置为: 0.743262
# 第148次优化的参数权重为: 0.730037, 偏置为: 0.743506
# 第149次优化的参数权重为: 0.730104, 偏置为: 0.744262
# 第150次优化的参数权重为: 0.729874, 偏置为: 0.744959
# 第151次优化的参数权重为: 0.729114, 偏置为: 0.745437
# 第152次优化的参数权重为: 0.729537, 偏置为: 0.746486
# 第153次优化的参数权重为: 0.729508, 偏置为: 0.747231
# 第154次优化的参数权重为: 0.727493, 偏置为: 0.747006
# 第155次优化的参数权重为: 0.727767, 偏置为: 0.748079
# 第156次优化的参数权重为: 0.727264, 偏置为: 0.748710
# 第157次优化的参数权重为: 0.725905, 偏置为: 0.748771
# 第158次优化的参数权重为: 0.725704, 偏置为: 0.749451
# 第159次优化的参数权重为: 0.726992, 偏置为: 0.750779
# 第160次优化的参数权重为: 0.726176, 偏置为: 0.751353
# 第161次优化的参数权重为: 0.726263, 偏置为: 0.752053
# 第162次优化的参数权重为: 0.724856, 偏置为: 0.752075
# 第163次优化的参数权重为: 0.724639, 偏置为: 0.752823
# 第164次优化的参数权重为: 0.724099, 偏置为: 0.753352
# 第165次优化的参数权重为: 0.724598, 偏置为: 0.754381
# 第166次优化的参数权重为: 0.724303, 偏置为: 0.754887
# 第167次优化的参数权重为: 0.724080, 偏置为: 0.755703
# 第168次优化的参数权重为: 0.724154, 偏置为: 0.756358
# 第169次优化的参数权重为: 0.723818, 偏置为: 0.756937
# 第170次优化的参数权重为: 0.723525, 偏置为: 0.757360
# 第171次优化的参数权重为: 0.722033, 偏置为: 0.757447
# 第172次优化的参数权重为: 0.722007, 偏置为: 0.758154
# 第173次优化的参数权重为: 0.722360, 偏置为: 0.758942
# 第174次优化的参数权重为: 0.721420, 偏置为: 0.758988
# 第175次优化的参数权重为: 0.721322, 偏置为: 0.759627
# 第176次优化的参数权重为: 0.721533, 偏置为: 0.760420
# 第177次优化的参数权重为: 0.720885, 偏置为: 0.760583
# 第178次优化的参数权重为: 0.720204, 偏置为: 0.760770
# 第179次优化的参数权重为: 0.720491, 偏置为: 0.761552
# 第180次优化的参数权重为: 0.720326, 偏置为: 0.762020
# 第181次优化的参数权重为: 0.719892, 偏置为: 0.762387
# 第182次优化的参数权重为: 0.719423, 偏置为: 0.762743
# 第183次优化的参数权重为: 0.719338, 偏置为: 0.763126
# 第184次优化的参数权重为: 0.718916, 偏置为: 0.763501
# 第185次优化的参数权重为: 0.718890, 偏置为: 0.764106
# 第186次优化的参数权重为: 0.719244, 偏置为: 0.764821
# 第187次优化的参数权重为: 0.718107, 偏置为: 0.764684
# 第188次优化的参数权重为: 0.717606, 偏置为: 0.764920
# 第189次优化的参数权重为: 0.718435, 偏置为: 0.766054
# 第190次优化的参数权重为: 0.718183, 偏置为: 0.766486
# 第191次优化的参数权重为: 0.718009, 偏置为: 0.766845
# 第192次优化的参数权重为: 0.717489, 偏置为: 0.767077
# 第193次优化的参数权重为: 0.716958, 偏置为: 0.767381
# 第194次优化的参数权重为: 0.716373, 偏置为: 0.767496
# 第195次优化的参数权重为: 0.716789, 偏置为: 0.768223
# 第196次优化的参数权重为: 0.717086, 偏置为: 0.768979
# 第197次优化的参数权重为: 0.716593, 偏置为: 0.769262
# 第198次优化的参数权重为: 0.716347, 偏置为: 0.769751
# 第199次优化的参数权重为: 0.716181, 偏置为: 0.770116
# 第200次优化的参数权重为: 0.716153, 偏置为: 0.770623
# 第201次优化的参数权重为: 0.715542, 偏置为: 0.770695
# 第202次优化的参数权重为: 0.715568, 偏置为: 0.771182
# 第203次优化的参数权重为: 0.714797, 偏置为: 0.771308
# 第204次优化的参数权重为: 0.714741, 偏置为: 0.771770
# 第205次优化的参数权重为: 0.714750, 偏置为: 0.772177
# 第206次优化的参数权重为: 0.714718, 偏置为: 0.772614
# 第207次优化的参数权重为: 0.714557, 偏置为: 0.772923
# 第208次优化的参数权重为: 0.714337, 偏置为: 0.773094
# 第209次优化的参数权重为: 0.714345, 偏置为: 0.773528
# 第210次优化的参数权重为: 0.714134, 偏置为: 0.773833
# 第211次优化的参数权重为: 0.714213, 偏置为: 0.774394
# 第212次优化的参数权重为: 0.713776, 偏置为: 0.774607
# 第213次优化的参数权重为: 0.713504, 偏置为: 0.774785
# 第214次优化的参数权重为: 0.713580, 偏置为: 0.775195
# 第215次优化的参数权重为: 0.713259, 偏置为: 0.775359
# 第216次优化的参数权重为: 0.712754, 偏置为: 0.775410
# 第217次优化的参数权重为: 0.712684, 偏置为: 0.775707
# 第218次优化的参数权重为: 0.712756, 偏置为: 0.776078
# 第219次优化的参数权重为: 0.712550, 偏置为: 0.776279
# 第220次优化的参数权重为: 0.712708, 偏置为: 0.776742
# 第221次优化的参数权重为: 0.712420, 偏置为: 0.776953
# 第222次优化的参数权重为: 0.712207, 偏置为: 0.777189
# 第223次优化的参数权重为: 0.712129, 偏置为: 0.777514
# 第224次优化的参数权重为: 0.711865, 偏置为: 0.777764
# 第225次优化的参数权重为: 0.712036, 偏置为: 0.778223
# 第226次优化的参数权重为: 0.711589, 偏置为: 0.778384
# 第227次优化的参数权重为: 0.711635, 偏置为: 0.778731
# 第228次优化的参数权重为: 0.711157, 偏置为: 0.778820
# 第229次优化的参数权重为: 0.710979, 偏置为: 0.779091
# 第230次优化的参数权重为: 0.711014, 偏置为: 0.779426
# 第231次优化的参数权重为: 0.711238, 偏置为: 0.779850
# 第232次优化的参数权重为: 0.710902, 偏置为: 0.780001
# 第233次优化的参数权重为: 0.710746, 偏置为: 0.780183
# 第234次优化的参数权重为: 0.710939, 偏置为: 0.780534
# 第235次优化的参数权重为: 0.710590, 偏置为: 0.780652
# 第236次优化的参数权重为: 0.710127, 偏置为: 0.780669
# 第237次优化的参数权重为: 0.710161, 偏置为: 0.780993
# 第238次优化的参数权重为: 0.710076, 偏置为: 0.781275
# 第239次优化的参数权重为: 0.710024, 偏置为: 0.781529
# 第240次优化的参数权重为: 0.709763, 偏置为: 0.781610
# 第241次优化的参数权重为: 0.709953, 偏置为: 0.782047
# 第242次优化的参数权重为: 0.709789, 偏置为: 0.782172
# 第243次优化的参数权重为: 0.709451, 偏置为: 0.782222
# 第244次优化的参数权重为: 0.709416, 偏置为: 0.782447
# 第245次优化的参数权重为: 0.709650, 偏置为: 0.782820
# 第246次优化的参数权重为: 0.709498, 偏置为: 0.782963
# 第247次优化的参数权重为: 0.708856, 偏置为: 0.782940
# 第248次优化的参数权重为: 0.708983, 偏置为: 0.783215
# 第249次优化的参数权重为: 0.709051, 偏置为: 0.783551
# 第250次优化的参数权重为: 0.708635, 偏置为: 0.783573
# 第251次优化的参数权重为: 0.708490, 偏置为: 0.783752
# 第252次优化的参数权重为: 0.708454, 偏置为: 0.783949
# 第253次优化的参数权重为: 0.708369, 偏置为: 0.784129
# 第254次优化的参数权重为: 0.708437, 偏置为: 0.784436
# 第255次优化的参数权重为: 0.708038, 偏置为: 0.784470
# 第256次优化的参数权重为: 0.708046, 偏置为: 0.784722
# 第257次优化的参数权重为: 0.708199, 偏置为: 0.785026
# 第258次优化的参数权重为: 0.707883, 偏置为: 0.785053
# 第259次优化的参数权重为: 0.707999, 偏置为: 0.785298
# 第260次优化的参数权重为: 0.707884, 偏置为: 0.785467
# 第261次优化的参数权重为: 0.707443, 偏置为: 0.785467
# 第262次优化的参数权重为: 0.707484, 偏置为: 0.785678
# 第263次优化的参数权重为: 0.707349, 偏置为: 0.785789
# 第264次优化的参数权重为: 0.707396, 偏置为: 0.786020
# 第265次优化的参数权重为: 0.707478, 偏置为: 0.786284
# 第266次优化的参数权重为: 0.707341, 偏置为: 0.786417
# 第267次优化的参数权重为: 0.707238, 偏置为: 0.786605
# 第268次优化的参数权重为: 0.707070, 偏置为: 0.786672
# 第269次优化的参数权重为: 0.707198, 偏置为: 0.786920
# 第270次优化的参数权重为: 0.706923, 偏置为: 0.786988
# 第271次优化的参数权重为: 0.707063, 偏置为: 0.787246
# 第272次优化的参数权重为: 0.706907, 偏置为: 0.787444
# 第273次优化的参数权重为: 0.706701, 偏置为: 0.787537
# 第274次优化的参数权重为: 0.706528, 偏置为: 0.787581
# 第275次优化的参数权重为: 0.706551, 偏置为: 0.787794
# 第276次优化的参数权重为: 0.706471, 偏置为: 0.787935
# 第277次优化的参数权重为: 0.706505, 偏置为: 0.788134
# 第278次优化的参数权重为: 0.706381, 偏置为: 0.788249
# 第279次优化的参数权重为: 0.706289, 偏置为: 0.788403
# 第280次优化的参数权重为: 0.706183, 偏置为: 0.788520
# 第281次优化的参数权重为: 0.706001, 偏置为: 0.788600
# 第282次优化的参数权重为: 0.706014, 偏置为: 0.788799
# 第283次优化的参数权重为: 0.705965, 偏置为: 0.788938
# 第284次优化的参数权重为: 0.705974, 偏置为: 0.789122
# 第285次优化的参数权重为: 0.705880, 偏置为: 0.789260
# 第286次优化的参数权重为: 0.705752, 偏置为: 0.789375
# 第287次优化的参数权重为: 0.705626, 偏置为: 0.789450
# 第288次优化的参数权重为: 0.705488, 偏置为: 0.789545
# 第289次优化的参数权重为: 0.705549, 偏置为: 0.789720
# 第290次优化的参数权重为: 0.705349, 偏置为: 0.789767
# 第291次优化的参数权重为: 0.705357, 偏置为: 0.789921
# 第292次优化的参数权重为: 0.705336, 偏置为: 0.790087
# 第293次优化的参数权重为: 0.705259, 偏置为: 0.790242
# 第294次优化的参数权重为: 0.705091, 偏置为: 0.790305
# 第295次优化的参数权重为: 0.705108, 偏置为: 0.790417
# 第296次优化的参数权重为: 0.705071, 偏置为: 0.790525
# 第297次优化的参数权重为: 0.704902, 偏置为: 0.790579
# 第298次优化的参数权重为: 0.704943, 偏置为: 0.790741
# 第299次优化的参数权重为: 0.704863, 偏置为: 0.790847
# 第300次优化的参数权重为: 0.704800, 偏置为: 0.790962
# 第301次优化的参数权重为: 0.704768, 偏置为: 0.791082
# 第302次优化的参数权重为: 0.704607, 偏置为: 0.791134
# 第303次优化的参数权重为: 0.704680, 偏置为: 0.791286
# 第304次优化的参数权重为: 0.704692, 偏置为: 0.791388
# 第305次优化的参数权重为: 0.704614, 偏置为: 0.791468
# 第306次优化的参数权重为: 0.704607, 偏置为: 0.791583
# 第307次优化的参数权重为: 0.704409, 偏置为: 0.791607
# 第308次优化的参数权重为: 0.704434, 偏置为: 0.791774
# 第309次优化的参数权重为: 0.704330, 偏置为: 0.791840
# 第310次优化的参数权重为: 0.704437, 偏置为: 0.792034
# 第311次优化的参数权重为: 0.704214, 偏置为: 0.792048
# 第312次优化的参数权重为: 0.704149, 偏置为: 0.792142
# 第313次优化的参数权重为: 0.704247, 偏置为: 0.792319
# 第314次优化的参数权重为: 0.704179, 偏置为: 0.792406
# 第315次优化的参数权重为: 0.704133, 偏置为: 0.792487
# 第316次优化的参数权重为: 0.704119, 偏置为: 0.792584
# 第317次优化的参数权重为: 0.704043, 偏置为: 0.792651
# 第318次优化的参数权重为: 0.704073, 偏置为: 0.792766
# 第319次优化的参数权重为: 0.703847, 偏置为: 0.792757
# 第320次优化的参数权重为: 0.703853, 偏置为: 0.792841
# 第321次优化的参数权重为: 0.703715, 偏置为: 0.792867
# 第322次优化的参数权重为: 0.703725, 偏置为: 0.792984
# 第323次优化的参数权重为: 0.703814, 偏置为: 0.793141
# 第324次优化的参数权重为: 0.703725, 偏置为: 0.793199
# 第325次优化的参数权重为: 0.703532, 偏置为: 0.793197
# 第326次优化的参数权重为: 0.703527, 偏置为: 0.793285
# 第327次优化的参数权重为: 0.703555, 偏置为: 0.793397
# 第328次优化的参数权重为: 0.703473, 偏置为: 0.793456
# 第329次优化的参数权重为: 0.703412, 偏置为: 0.793520
# 第330次优化的参数权重为: 0.703559, 偏置为: 0.793667
# 第331次优化的参数权重为: 0.703407, 偏置为: 0.793671
# 第332次优化的参数权重为: 0.703338, 偏置为: 0.793721
# 第333次优化的参数权重为: 0.703299, 偏置为: 0.793787
# 第334次优化的参数权重为: 0.703369, 偏置为: 0.793921
# 第335次优化的参数权重为: 0.703231, 偏置为: 0.793919
# 第336次优化的参数权重为: 0.703274, 偏置为: 0.794057
# 第337次优化的参数权重为: 0.703107, 偏置为: 0.794061
# 第338次优化的参数权重为: 0.703148, 偏置为: 0.794177
# 第339次优化的参数权重为: 0.703103, 偏置为: 0.794257
# 第340次优化的参数权重为: 0.703124, 偏置为: 0.794348
# 第341次优化的参数权重为: 0.703022, 偏置为: 0.794389
# 第342次优化的参数权重为: 0.702998, 偏置为: 0.794465
# 第343次优化的参数权重为: 0.702912, 偏置为: 0.794501
# 第344次优化的参数权重为: 0.702896, 偏置为: 0.794575
# 第345次优化的参数权重为: 0.702836, 偏置为: 0.794631
# 第346次优化的参数权重为: 0.702961, 偏置为: 0.794771
# 第347次优化的参数权重为: 0.702826, 偏置为: 0.794773
# 第348次优化的参数权重为: 0.702828, 偏置为: 0.794848
# 第349次优化的参数权重为: 0.702736, 偏置为: 0.794855
# 第350次优化的参数权重为: 0.702748, 偏置为: 0.794935
# 第351次优化的参数权重为: 0.702648, 偏置为: 0.794937
# 第352次优化的参数权重为: 0.702591, 偏置为: 0.795014
# 第353次优化的参数权重为: 0.702664, 偏置为: 0.795133
# 第354次优化的参数权重为: 0.702520, 偏置为: 0.795132
# 第355次优化的参数权重为: 0.702577, 偏置为: 0.795227
# 第356次优化的参数权重为: 0.702569, 偏置为: 0.795284
# 第357次优化的参数权重为: 0.702513, 偏置为: 0.795326
# 第358次优化的参数权重为: 0.702564, 偏置为: 0.795438
# 第359次优化的参数权重为: 0.702471, 偏置为: 0.795458
# 第360次优化的参数权重为: 0.702458, 偏置为: 0.795523
# 第361次优化的参数权重为: 0.702337, 偏置为: 0.795525
# 第362次优化的参数权重为: 0.702376, 偏置为: 0.795616
# 第363次优化的参数权重为: 0.702345, 偏置为: 0.795663
# 第364次优化的参数权重为: 0.702334, 偏置为: 0.795712
# 第365次优化的参数权重为: 0.702352, 偏置为: 0.795776
# 第366次优化的参数权重为: 0.702262, 偏置为: 0.795785
# 第367次优化的参数权重为: 0.702261, 偏置为: 0.795849
# 第368次优化的参数权重为: 0.702104, 偏置为: 0.795824
# 第369次优化的参数权重为: 0.702171, 偏置为: 0.795923
# 第370次优化的参数权重为: 0.702127, 偏置为: 0.795955
# 第371次优化的参数权重为: 0.702105, 偏置为: 0.795998
# 第372次优化的参数权重为: 0.702096, 偏置为: 0.796054
# 第373次优化的参数权重为: 0.701997, 偏置为: 0.796068
# 第374次优化的参数权重为: 0.701987, 偏置为: 0.796126
# 第375次优化的参数权重为: 0.702021, 偏置为: 0.796203
# 第376次优化的参数权重为: 0.702019, 偏置为: 0.796243
# 第377次优化的参数权重为: 0.702028, 偏置为: 0.796296
# 第378次优化的参数权重为: 0.701880, 偏置为: 0.796289
# 第379次优化的参数权重为: 0.701969, 偏置为: 0.796386
# 第380次优化的参数权重为: 0.701868, 偏置为: 0.796388
# 第381次优化的参数权重为: 0.701902, 偏置为: 0.796450
# 第382次优化的参数权重为: 0.701878, 偏置为: 0.796493
# 第383次优化的参数权重为: 0.701830, 偏置为: 0.796522
# 第384次优化的参数权重为: 0.701821, 偏置为: 0.796578
# 第385次优化的参数权重为: 0.701809, 偏置为: 0.796617
# 第386次优化的参数权重为: 0.701801, 偏置为: 0.796666
# 第387次优化的参数权重为: 0.701805, 偏置为: 0.796724
# 第388次优化的参数权重为: 0.701754, 偏置为: 0.796745
# 第389次优化的参数权重为: 0.701698, 偏置为: 0.796763
# 第390次优化的参数权重为: 0.701715, 偏置为: 0.796825
# 第391次优化的参数权重为: 0.701664, 偏置为: 0.796835
# 第392次优化的参数权重为: 0.701677, 偏置为: 0.796883
# 第393次优化的参数权重为: 0.701657, 偏置为: 0.796929
# 第394次优化的参数权重为: 0.701647, 偏置为: 0.796963
# 第395次优化的参数权重为: 0.701620, 偏置为: 0.796999
# 第396次优化的参数权重为: 0.701556, 偏置为: 0.797022
# 第397次优化的参数权重为: 0.701523, 偏置为: 0.797051
# 第398次优化的参数权重为: 0.701561, 偏置为: 0.797115
# 第399次优化的参数权重为: 0.701586, 偏置为: 0.797172
# 第400次优化的参数权重为: 0.701493, 偏置为: 0.797160
# 第401次优化的参数权重为: 0.701483, 偏置为: 0.797193
# 第402次优化的参数权重为: 0.701485, 偏置为: 0.797239
# 第403次优化的参数权重为: 0.701439, 偏置为: 0.797254
# 第404次优化的参数权重为: 0.701475, 偏置为: 0.797303
# 第405次优化的参数权重为: 0.701448, 偏置为: 0.797330
# 第406次优化的参数权重为: 0.701472, 偏置为: 0.797386
# 第407次优化的参数权重为: 0.701428, 偏置为: 0.797397
# 第408次优化的参数权重为: 0.701383, 偏置为: 0.797417
# 第409次优化的参数权重为: 0.701346, 偏置为: 0.797433
# 第410次优化的参数权重为: 0.701290, 偏置为: 0.797439
# 第411次优化的参数权重为: 0.701331, 偏置为: 0.797491
# 第412次优化的参数权重为: 0.701360, 偏置为: 0.797544
# 第413次优化的参数权重为: 0.701287, 偏置为: 0.797541
# 第414次优化的参数权重为: 0.701269, 偏置为: 0.797579
# 第415次优化的参数权重为: 0.701259, 偏置为: 0.797607
# 第416次优化的参数权重为: 0.701272, 偏置为: 0.797651
# 第417次优化的参数权重为: 0.701247, 偏置为: 0.797671
# 第418次优化的参数权重为: 0.701264, 偏置为: 0.797710
# 第419次优化的参数权重为: 0.701216, 偏置为: 0.797722
# 第420次优化的参数权重为: 0.701221, 偏置为: 0.797762
# 第421次优化的参数权重为: 0.701190, 偏置为: 0.797785
# 第422次优化的参数权重为: 0.701206, 偏置为: 0.797821
# 第423次优化的参数权重为: 0.701195, 偏置为: 0.797850
# 第424次优化的参数权重为: 0.701167, 偏置为: 0.797867
# 第425次优化的参数权重为: 0.701169, 偏置为: 0.797901
# 第426次优化的参数权重为: 0.701147, 偏置为: 0.797916
# 第427次优化的参数权重为: 0.701083, 偏置为: 0.797917
# 第428次优化的参数权重为: 0.701106, 偏置为: 0.797966
# 第429次优化的参数权重为: 0.701109, 偏置为: 0.798004
# 第430次优化的参数权重为: 0.701089, 偏置为: 0.798023
# 第431次优化的参数权重为: 0.701081, 偏置为: 0.798051
# 第432次优化的参数权重为: 0.701065, 偏置为: 0.798073
# 第433次优化的参数权重为: 0.701037, 偏置为: 0.798082
# 第434次优化的参数权重为: 0.700989, 偏置为: 0.798086
# 第435次优化的参数权重为: 0.700988, 偏置为: 0.798110
# 第436次优化的参数权重为: 0.701006, 偏置为: 0.798141
# 第437次优化的参数权重为: 0.701013, 偏置为: 0.798174
# 第438次优化的参数权重为: 0.700966, 偏置为: 0.798174
# 第439次优化的参数权重为: 0.700958, 偏置为: 0.798192
# 第440次优化的参数权重为: 0.700971, 偏置为: 0.798223
# 第441次优化的参数权重为: 0.700959, 偏置为: 0.798251
# 第442次优化的参数权重为: 0.700959, 偏置为: 0.798273
# 第443次优化的参数权重为: 0.700916, 偏置为: 0.798268
# 第444次优化的参数权重为: 0.700919, 偏置为: 0.798293
# 第445次优化的参数权重为: 0.700920, 偏置为: 0.798314
# 第446次优化的参数权重为: 0.700891, 偏置为: 0.798324
# 第447次优化的参数权重为: 0.700870, 偏置为: 0.798333
# 第448次优化的参数权重为: 0.700881, 偏置为: 0.798363
# 第449次优化的参数权重为: 0.700860, 偏置为: 0.798380
# 第450次优化的参数权重为: 0.700847, 偏置为: 0.798401
# 第451次优化的参数权重为: 0.700848, 偏置为: 0.798428
# 第452次优化的参数权重为: 0.700831, 偏置为: 0.798443
# 第453次优化的参数权重为: 0.700805, 偏置为: 0.798453
# 第454次优化的参数权重为: 0.700837, 偏置为: 0.798496
# 第455次优化的参数权重为: 0.700811, 偏置为: 0.798504
# 第456次优化的参数权重为: 0.700792, 偏置为: 0.798518
# 第457次优化的参数权重为: 0.700779, 偏置为: 0.798535
# 第458次优化的参数权重为: 0.700771, 偏置为: 0.798550
# 第459次优化的参数权重为: 0.700752, 偏置为: 0.798565
# 第460次优化的参数权重为: 0.700769, 偏置为: 0.798597
# 第461次优化的参数权重为: 0.700742, 偏置为: 0.798603
# 第462次优化的参数权重为: 0.700748, 偏置为: 0.798635
# 第463次优化的参数权重为: 0.700732, 偏置为: 0.798645
# 第464次优化的参数权重为: 0.700743, 偏置为: 0.798674
# 第465次优化的参数权重为: 0.700721, 偏置为: 0.798686
# 第466次优化的参数权重为: 0.700685, 偏置为: 0.798689
# 第467次优化的参数权重为: 0.700674, 偏置为: 0.798703
# 第468次优化的参数权重为: 0.700683, 偏置为: 0.798723
# 第469次优化的参数权重为: 0.700685, 偏置为: 0.798747
# 第470次优化的参数权重为: 0.700688, 偏置为: 0.798768
# 第471次优化的参数权重为: 0.700665, 偏置为: 0.798770
# 第472次优化的参数权重为: 0.700674, 偏置为: 0.798792
# 第473次优化的参数权重为: 0.700630, 偏置为: 0.798787
# 第474次优化的参数权重为: 0.700649, 偏置为: 0.798811
# 第475次优化的参数权重为: 0.700617, 偏置为: 0.798813
# 第476次优化的参数权重为: 0.700622, 偏置为: 0.798833
# 第477次优化的参数权重为: 0.700606, 偏置为: 0.798840
# 第478次优化的参数权重为: 0.700612, 偏置为: 0.798861
# 第479次优化的参数权重为: 0.700606, 偏置为: 0.798872
# 第480次优化的参数权重为: 0.700611, 偏置为: 0.798893
# 第481次优化的参数权重为: 0.700593, 偏置为: 0.798898
# 第482次优化的参数权重为: 0.700579, 偏置为: 0.798908
# 第483次优化的参数权重为: 0.700585, 偏置为: 0.798927
# 第484次优化的参数权重为: 0.700561, 偏置为: 0.798930
# 第485次优化的参数权重为: 0.700567, 偏置为: 0.798947
# 第486次优化的参数权重为: 0.700548, 偏置为: 0.798952
# 第487次优化的参数权重为: 0.700553, 偏置为: 0.798968
# 第488次优化的参数权重为: 0.700533, 偏置为: 0.798969
# 第489次优化的参数权重为: 0.700539, 偏置为: 0.798986
# 第490次优化的参数权重为: 0.700528, 偏置为: 0.798995
# 第491次优化的参数权重为: 0.700532, 偏置为: 0.799010
# 第492次优化的参数权重为: 0.700530, 偏置为: 0.799021
# 第493次优化的参数权重为: 0.700510, 偏置为: 0.799028
# 第494次优化的参数权重为: 0.700517, 偏置为: 0.799043
# 第495次优化的参数权重为: 0.700515, 偏置为: 0.799057
# 第496次优化的参数权重为: 0.700517, 偏置为: 0.799077
# 第497次优化的参数权重为: 0.700495, 偏置为: 0.799078
# 第498次优化的参数权重为: 0.700473, 偏置为: 0.799079
# 第499次优化的参数权重为: 0.700478, 偏置为: 0.799095
