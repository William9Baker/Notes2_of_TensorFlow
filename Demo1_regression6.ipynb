# %%
import tensorflow as tf

def myregression():
    with tf.variable_scope("data"):   # tf的变量作用域
        # 1、准备数据，x 特征值 [100, 1]   （100个样本，1个特征）
        x = tf.random_normal([100, 1], mean=1.75, stddev=0.5, name="x_data")
        y_true = tf.matmul(x, [[0.7]]) + 0.8

    with tf.variable_scope("model"):
        # weight也是一个op
        weight = tf.Variable(tf.random_normal([1, 1], mean=0.0, stddev=1.0), name="weight", trainable=True)
        bias = tf.Variable(0.0, name="b")    # 初始化为0.0

        y_predict = tf.matmul(x, weight) + bias

    with tf.variable_scope("loss"):
        loss = tf.reduce_mean(tf.square(y_true - y_predict))

    with tf.variable_scope("optimizer"):
        train_op = tf.train.GradientDescentOptimizer(0.1).minimize(loss)

    # 定义一个初始化变量的op
    initializer_op = tf.global_variables_initializer()  # 初始化变量weight和bias

    with tf.Session() as sess:
        sess.run(initializer_op)
        print("随机初始化的参数权重为: %f, 偏置为: %f" % (weight.eval(), bias.eval()))

        filewriter = tf.summary.FileWriter("F:/TensorFlow/logs", graph=sess.graph)
       # 循环训练
        for i in range(500):
            sess.run(train_op)
            print("第%d次优化的参数权重为: %f, 偏置为: %f" % (i, weight.eval(), bias.eval()))

    return None

if __name__ == "__main__":
    myregression()
# Out:
# 随机初始化的参数权重为: 0.384638, 偏置为: 0.000000
# 第0次优化的参数权重为: 0.863148, 偏置为: 0.268521
# 第1次优化的参数权重为: 0.939797, 偏置为: 0.314129
# 第2次优化的参数权重为: 0.948004, 偏置为: 0.326331
# 第3次优化的参数权重为: 0.954707, 偏置为: 0.337628
# 第4次优化的参数权重为: 0.939346, 偏置为: 0.336807
# 第5次优化的参数权重为: 0.938177, 偏置为: 0.344475
# 第6次优化的参数权重为: 0.948974, 偏置为: 0.356141
# 第7次优化的参数权重为: 0.941284, 偏置为: 0.358048
# 第8次优化的参数权重为: 0.932849, 偏置为: 0.359813
# 第9次优化的参数权重为: 0.936645, 偏置为: 0.368324
# 第10次优化的参数权重为: 0.924428, 偏置为: 0.368648
# 第11次优化的参数权重为: 0.926745, 偏置为: 0.376218
# 第12次优化的参数权重为: 0.923544, 偏置为: 0.379675
# 第13次优化的参数权重为: 0.927438, 偏置为: 0.387939
# 第14次优化的参数权重为: 0.919197, 偏置为: 0.390371
# 第15次优化的参数权重为: 0.913574, 偏置为: 0.393329
# 第16次优化的参数权重为: 0.910733, 偏置为: 0.398173
# 第17次优化的参数权重为: 0.907188, 偏置为: 0.401964
# 第18次优化的参数权重为: 0.907295, 偏置为: 0.407458
# 第19次优化的参数权重为: 0.912728, 偏置为: 0.416010
# 第20次优化的参数权重为: 0.910261, 偏置为: 0.421062
# 第21次优化的参数权重为: 0.901158, 偏置为: 0.422971
# 第22次优化的参数权重为: 0.899329, 偏置为: 0.427935
# 第23次优化的参数权重为: 0.893014, 偏置为: 0.431808
# 第24次优化的参数权重为: 0.893857, 偏置为: 0.437339
# 第25次优化的参数权重为: 0.892621, 偏置为: 0.442615
# 第26次优化的参数权重为: 0.891071, 偏置为: 0.446828
# 第27次优化的参数权重为: 0.889174, 偏置为: 0.450597
# 第28次优化的参数权重为: 0.886514, 偏置为: 0.453593
# 第29次优化的参数权重为: 0.880113, 偏置为: 0.455291
# 第30次优化的参数权重为: 0.883959, 偏置为: 0.462343
# 第31次优化的参数权重为: 0.880423, 偏置为: 0.467572
# 第32次优化的参数权重为: 0.873379, 偏置为: 0.468242
# 第33次优化的参数权重为: 0.871563, 偏置为: 0.472523
# 第34次优化的参数权重为: 0.873789, 偏置为: 0.478122
# 第35次优化的参数权重为: 0.872615, 偏置为: 0.482011
# 第36次优化的参数权重为: 0.868371, 偏置为: 0.483888
# 第37次优化的参数权重为: 0.866453, 偏置为: 0.488046
# 第38次优化的参数权重为: 0.866261, 偏置为: 0.491477
# 第39次优化的参数权重为: 0.865911, 偏置为: 0.496082
# 第40次优化的参数权重为: 0.863852, 偏置为: 0.499425
# 第41次优化的参数权重为: 0.860168, 偏置为: 0.502097
# 第42次优化的参数权重为: 0.855753, 偏置为: 0.504592
# 第43次优化的参数权重为: 0.860210, 偏置为: 0.511121
# 第44次优化的参数权重为: 0.856789, 偏置为: 0.512812
# 第45次优化的参数权重为: 0.852074, 偏置为: 0.513284
# 第46次优化的参数权重为: 0.853819, 偏置为: 0.518003
# 第47次优化的参数权重为: 0.849002, 偏置为: 0.519695
# 第48次优化的参数权重为: 0.850770, 偏置为: 0.524430
# 第49次优化的参数权重为: 0.847596, 偏置为: 0.527205
# 第50次优化的参数权重为: 0.847608, 偏置为: 0.530646
# 第51次优化的参数权重为: 0.846420, 偏置为: 0.534519
# 第52次优化的参数权重为: 0.837065, 偏置为: 0.534257
# 第53次优化的参数权重为: 0.842123, 偏置为: 0.542110
# 第54次优化的参数权重为: 0.837413, 偏置为: 0.543218
# 第55次优化的参数权重为: 0.837947, 偏置为: 0.547537
# 第56次优化的参数权重为: 0.835753, 偏置为: 0.549759
# 第57次优化的参数权重为: 0.829749, 偏置为: 0.549853
# 第58次优化的参数权重为: 0.830120, 偏置为: 0.553399
# 第59次优化的参数权重为: 0.832234, 偏置为: 0.558723
# 第60次优化的参数权重为: 0.826993, 偏置为: 0.559893
# 第61次优化的参数权重为: 0.827692, 偏置为: 0.563377
# 第62次优化的参数权重为: 0.826044, 偏置为: 0.566253
# 第63次优化的参数权重为: 0.824710, 偏置为: 0.569876
# 第64次优化的参数权重为: 0.826161, 偏置为: 0.573910
# 第65次优化的参数权重为: 0.819619, 偏置为: 0.573956
# 第66次优化的参数权重为: 0.820109, 偏置为: 0.577660
# 第67次优化的参数权重为: 0.821139, 偏置为: 0.581669
# 第68次优化的参数权重为: 0.814039, 偏置为: 0.581103
# 第69次优化的参数权重为: 0.816312, 偏置为: 0.585678
# 第70次优化的参数权重为: 0.812709, 偏置为: 0.588413
# 第71次优化的参数权重为: 0.813579, 偏置为: 0.591616
# 第72次优化的参数权重为: 0.811537, 偏置为: 0.593716
# 第73次优化的参数权重为: 0.809240, 偏置为: 0.595231
# 第74次优化的参数权重为: 0.806432, 偏置为: 0.596360
# 第75次优化的参数权重为: 0.808749, 偏置为: 0.600528
# 第76次优化的参数权重为: 0.807493, 偏置为: 0.602907
# 第77次优化的参数权重为: 0.806148, 偏置为: 0.604959
# 第78次优化的参数权重为: 0.804064, 偏置为: 0.606840
# 第79次优化的参数权重为: 0.804877, 偏置为: 0.609980
# 第80次优化的参数权重为: 0.804019, 偏置为: 0.612103
# 第81次优化的参数权重为: 0.802670, 偏置为: 0.613627
# 第82次优化的参数权重为: 0.803070, 偏置为: 0.617167
# 第83次优化的参数权重为: 0.798148, 偏置为: 0.617833
# 第84次优化的参数权重为: 0.795341, 偏置为: 0.619638
# 第85次优化的参数权重为: 0.796934, 偏置为: 0.624419
# 第86次优化的参数权重为: 0.791442, 偏置为: 0.624336
# 第87次优化的参数权重为: 0.793794, 偏置为: 0.628239
# 第88次优化的参数权重为: 0.790691, 偏置为: 0.629326
# 第89次优化的参数权重为: 0.790373, 偏置为: 0.632670
# 第90次优化的参数权重为: 0.787682, 偏置为: 0.634037
# 第91次优化的参数权重为: 0.786999, 偏置为: 0.636535
# 第92次优化的参数权重为: 0.785870, 偏置为: 0.638324
# 第93次优化的参数权重为: 0.787690, 偏置为: 0.642011
# 第94次优化的参数权重为: 0.786786, 偏置为: 0.643634
# 第95次优化的参数权重为: 0.784454, 偏置为: 0.644904
# 第96次优化的参数权重为: 0.780558, 偏置为: 0.645205
# 第97次优化的参数权重为: 0.780764, 偏置为: 0.647507
# 第98次优化的参数权重为: 0.778913, 偏置为: 0.648563
# 第99次优化的参数权重为: 0.779197, 偏置为: 0.650734
# 第100次优化的参数权重为: 0.778206, 偏置为: 0.652377
# 第101次优化的参数权重为: 0.777140, 偏置为: 0.654894
# 第102次优化的参数权重为: 0.775266, 偏置为: 0.656229
# 第103次优化的参数权重为: 0.775912, 偏置为: 0.659183
# 第104次优化的参数权重为: 0.773776, 偏置为: 0.659610
# 第105次优化的参数权重为: 0.773084, 偏置为: 0.661089
# 第106次优化的参数权重为: 0.773578, 偏置为: 0.663671
# 第107次优化的参数权重为: 0.772959, 偏置为: 0.665671
# 第108次优化的参数权重为: 0.770249, 偏置为: 0.666346
# 第109次优化的参数权重为: 0.770394, 偏置为: 0.668363
# 第110次优化的参数权重为: 0.769670, 偏置为: 0.669717
# 第111次优化的参数权重为: 0.770742, 偏置为: 0.672395
# 第112次优化的参数权重为: 0.766830, 偏置为: 0.671921
# 第113次优化的参数权重为: 0.768016, 偏置为: 0.674588
# 第114次优化的参数权重为: 0.767735, 偏置为: 0.675957
# 第115次优化的参数权重为: 0.764138, 偏置为: 0.676329
# 第116次优化的参数权重为: 0.765068, 偏置为: 0.677972
# 第117次优化的参数权重为: 0.764369, 偏置为: 0.678837
# 第118次优化的参数权重为: 0.765006, 偏置为: 0.681433
# 第119次优化的参数权重为: 0.764174, 偏置为: 0.682969
# 第120次优化的参数权重为: 0.761683, 偏置为: 0.683277
# 第121次优化的参数权重为: 0.759460, 偏置为: 0.683621
# 第122次优化的参数权重为: 0.761928, 偏置为: 0.686685
# 第123次优化的参数权重为: 0.759523, 偏置为: 0.687045
# 第124次优化的参数权重为: 0.759586, 偏置为: 0.688568
# 第125次优化的参数权重为: 0.758391, 偏置为: 0.689410
# 第126次优化的参数权重为: 0.758895, 偏置为: 0.691473
# 第127次优化的参数权重为: 0.757359, 偏置为: 0.692302
# 第128次优化的参数权重为: 0.755044, 偏置为: 0.692878
# 第129次优化的参数权重为: 0.756104, 偏置为: 0.695139
# 第130次优化的参数权重为: 0.755032, 偏置为: 0.696365
# 第131次优化的参数权重为: 0.755111, 偏置为: 0.697922
# 第132次优化的参数权重为: 0.753519, 偏置为: 0.698796
# 第133次优化的参数权重为: 0.754885, 偏置为: 0.701183
# 第134次优化的参数权重为: 0.753411, 偏置为: 0.702127
# 第135次优化的参数权重为: 0.753431, 偏置为: 0.704010
# 第136次优化的参数权重为: 0.751093, 偏置为: 0.704250
# 第137次优化的参数权重为: 0.751840, 偏置为: 0.705673
# 第138次优化的参数权重为: 0.750439, 偏置为: 0.706691
# 第139次优化的参数权重为: 0.746956, 偏置为: 0.706559
# 第140次优化的参数权重为: 0.748774, 偏置为: 0.709069
# 第141次优化的参数权重为: 0.747739, 偏置为: 0.709717
# 第142次优化的参数权重为: 0.747012, 偏置为: 0.710690
# 第143次优化的参数权重为: 0.748470, 偏置为: 0.712640
# 第144次优化的参数权重为: 0.745832, 偏置为: 0.712892
# 第145次优化的参数权重为: 0.746869, 偏置为: 0.714769
# 第146次优化的参数权重为: 0.744716, 偏置为: 0.714978
# 第147次优化的参数权重为: 0.744522, 偏置为: 0.716300
# 第148次优化的参数权重为: 0.744975, 偏置为: 0.717884
# 第149次优化的参数权重为: 0.741848, 偏置为: 0.717587
# 第150次优化的参数权重为: 0.742621, 偏置为: 0.718923
# 第151次优化的参数权重为: 0.743795, 偏置为: 0.720698
# 第152次优化的参数权重为: 0.743240, 偏置为: 0.721644
# 第153次优化的参数权重为: 0.741408, 偏置为: 0.721687
# 第154次优化的参数权重为: 0.740736, 偏置为: 0.722296
# 第155次优化的参数权重为: 0.741780, 偏置为: 0.724013
# 第156次优化的参数权重为: 0.740036, 偏置为: 0.724350
# 第157次优化的参数权重为: 0.740874, 偏置为: 0.726016
# 第158次优化的参数权重为: 0.740350, 偏置为: 0.726798
# 第159次优化的参数权重为: 0.737865, 偏置为: 0.726764
# 第160次优化的参数权重为: 0.738567, 偏置为: 0.728070
# 第161次优化的参数权重为: 0.738453, 偏置为: 0.729293
# 第162次优化的参数权重为: 0.737206, 偏置为: 0.729887
# 第163次优化的参数权重为: 0.737344, 偏置为: 0.730913
# 第164次优化的参数权重为: 0.737539, 偏置为: 0.731904
# 第165次优化的参数权重为: 0.737410, 偏置为: 0.732716
# 第166次优化的参数权重为: 0.735655, 偏置为: 0.732820
# 第167次优化的参数权重为: 0.734812, 偏置为: 0.733567
# 第168次优化的参数权重为: 0.735579, 偏置为: 0.735194
# 第169次优化的参数权重为: 0.733243, 偏置为: 0.735032
# 第170次优化的参数权重为: 0.733431, 偏置为: 0.736353
# 第171次优化的参数权重为: 0.733257, 偏置为: 0.737140
# 第172次优化的参数权重为: 0.732936, 偏置为: 0.737831
# 第173次优化的参数权重为: 0.733557, 偏置为: 0.739025
# 第174次优化的参数权重为: 0.734466, 偏置为: 0.740331
# 第175次优化的参数权重为: 0.730748, 偏置为: 0.739343
# 第176次优化的参数权重为: 0.731107, 偏置为: 0.740258
# 第177次优化的参数权重为: 0.730802, 偏置为: 0.740986
# 第178次优化的参数权重为: 0.731114, 偏置为: 0.742022
# 第179次优化的参数权重为: 0.730089, 偏置为: 0.742490
# 第180次优化的参数权重为: 0.730040, 偏置为: 0.743264
# 第181次优化的参数权重为: 0.730170, 偏置为: 0.744140
# 第182次优化的参数权重为: 0.729060, 偏置为: 0.744484
# 第183次优化的参数权重为: 0.729043, 偏置为: 0.745448
# 第184次优化的参数权重为: 0.728443, 偏置为: 0.745797
# 第185次优化的参数权重为: 0.728389, 偏置为: 0.746628
# 第186次优化的参数权重为: 0.728970, 偏置为: 0.747581
# 第187次优化的参数权重为: 0.727817, 偏置为: 0.747653
# 第188次优化的参数权重为: 0.727848, 偏置为: 0.748584
# 第189次优化的参数权重为: 0.727726, 偏置为: 0.749245
# 第190次优化的参数权重为: 0.726271, 偏置为: 0.749503
# 第191次优化的参数权重为: 0.725955, 偏置为: 0.750251
# 第192次优化的参数权重为: 0.726071, 偏置为: 0.751005
# 第193次优化的参数权重为: 0.726613, 偏置为: 0.752163
# 第194次优化的参数权重为: 0.726142, 偏置为: 0.752647
# 第195次优化的参数权重为: 0.725033, 偏置为: 0.752834
# 第196次优化的参数权重为: 0.725649, 偏置为: 0.753770
# 第197次优化的参数权重为: 0.724470, 偏置为: 0.754012
# 第198次优化的参数权重为: 0.723981, 偏置为: 0.754492
# 第199次优化的参数权重为: 0.723172, 偏置为: 0.754796
# 第200次优化的参数权重为: 0.723594, 偏置为: 0.755669
# 第201次优化的参数权重为: 0.723345, 偏置为: 0.756119
# 第202次优化的参数权重为: 0.722705, 偏置为: 0.756387
# 第203次优化的参数权重为: 0.723189, 偏置为: 0.757238
# 第204次优化的参数权重为: 0.723355, 偏置为: 0.758156
# 第205次优化的参数权重为: 0.722429, 偏置为: 0.758241
# 第206次优化的参数权重为: 0.722359, 偏置为: 0.758855
# 第207次优化的参数权重为: 0.721953, 偏置为: 0.759185
# 第208次优化的参数权重为: 0.721999, 偏置为: 0.759834
# 第209次优化的参数权重为: 0.721881, 偏置为: 0.760546
# 第210次优化的参数权重为: 0.720982, 偏置为: 0.760654
# 第211次优化的参数权重为: 0.721177, 偏置为: 0.761428
# 第212次优化的参数权重为: 0.720090, 偏置为: 0.761305
# 第213次优化的参数权重为: 0.720335, 偏置为: 0.761973
# 第214次优化的参数权重为: 0.720351, 偏置为: 0.762497
# 第215次优化的参数权重为: 0.719579, 偏置为: 0.762691
# 第216次优化的参数权重为: 0.719238, 偏置为: 0.763024
# 第217次优化的参数权重为: 0.719535, 偏置为: 0.763597
# 第218次优化的参数权重为: 0.719234, 偏置为: 0.763877
# 第219次优化的参数权重为: 0.719321, 偏置为: 0.764438
# 第220次优化的参数权重为: 0.718818, 偏置为: 0.764614
# 第221次优化的参数权重为: 0.717996, 偏置为: 0.764833
# 第222次优化的参数权重为: 0.717903, 偏置为: 0.765334
# 第223次优化的参数权重为: 0.717946, 偏置为: 0.765905
# 第224次优化的参数权重为: 0.717793, 偏置为: 0.766311
# 第225次优化的参数权重为: 0.717687, 偏置为: 0.766849
# 第226次优化的参数权重为: 0.717689, 偏置为: 0.767399
# 第227次优化的参数权重为: 0.716951, 偏置为: 0.767546
# 第228次优化的参数权重为: 0.717263, 偏置为: 0.768287
# 第229次优化的参数权重为: 0.716439, 偏置为: 0.768370
# 第230次优化的参数权重为: 0.716624, 偏置为: 0.768945
# 第231次优化的参数权重为: 0.716894, 偏置为: 0.769485
# 第232次优化的参数权重为: 0.716172, 偏置为: 0.769557
# 第233次优化的参数权重为: 0.716224, 偏置为: 0.770035
# 第234次优化的参数权重为: 0.716052, 偏置为: 0.770380
# 第235次优化的参数权重为: 0.716333, 偏置为: 0.771009
# 第236次优化的参数权重为: 0.715872, 偏置为: 0.771350
# 第237次优化的参数权重为: 0.714723, 偏置为: 0.771128
# 第238次优化的参数权重为: 0.714923, 偏置为: 0.771620
# 第239次优化的参数权重为: 0.714986, 偏置为: 0.772129
# 第240次优化的参数权重为: 0.714969, 偏置为: 0.772510
# 第241次优化的参数权重为: 0.714682, 偏置为: 0.772743
# 第242次优化的参数权重为: 0.714361, 偏置为: 0.772951
# 第243次优化的参数权重为: 0.714048, 偏置为: 0.773148
# 第244次优化的参数权重为: 0.714077, 偏置为: 0.773611
# 第245次优化的参数权重为: 0.713845, 偏置为: 0.773964
# 第246次优化的参数权重为: 0.713586, 偏置为: 0.774229
# 第247次优化的参数权重为: 0.713917, 偏置为: 0.774833
# 第248次优化的参数权重为: 0.713318, 偏置为: 0.774813
# 第249次优化的参数权重为: 0.712984, 偏置为: 0.775079
# 第250次优化的参数权重为: 0.712993, 偏置为: 0.775547
# 第251次优化的参数权重为: 0.712679, 偏置为: 0.775681
# 第252次优化的参数权重为: 0.712817, 偏置为: 0.776147
# 第253次优化的参数权重为: 0.712920, 偏置为: 0.776589
# 第254次优化的参数权重为: 0.712304, 偏置为: 0.776657
# 第255次优化的参数权重为: 0.712197, 偏置为: 0.776959
# 第256次优化的参数权重为: 0.712060, 偏置为: 0.777234
# 第257次优化的参数权重为: 0.712344, 偏置为: 0.777791
# 第258次优化的参数权重为: 0.711930, 偏置为: 0.777946
# 第259次优化的参数权重为: 0.711816, 偏置为: 0.778222
# 第260次优化的参数权重为: 0.711606, 偏置为: 0.778496
# 第261次优化的参数权重为: 0.711393, 偏置为: 0.778631
# 第262次优化的参数权重为: 0.711497, 偏置为: 0.779028
# 第263次优化的参数权重为: 0.711177, 偏置为: 0.779134
# 第264次优化的参数权重为: 0.710859, 偏置为: 0.779326
# 第265次优化的参数权重为: 0.710836, 偏置为: 0.779648
# 第266次优化的参数权重为: 0.710698, 偏置为: 0.779892
# 第267次优化的参数权重为: 0.710298, 偏置为: 0.779928
# 第268次优化的参数权重为: 0.710699, 偏置为: 0.780404
# 第269次优化的参数权重为: 0.710456, 偏置为: 0.780541
# 第270次优化的参数权重为: 0.710184, 偏置为: 0.780685
# 第271次优化的参数权重为: 0.710383, 偏置为: 0.781077
# 第272次优化的参数权重为: 0.709903, 偏置为: 0.781115
# 第273次优化的参数权重为: 0.710013, 偏置为: 0.781511
# 第274次优化的参数权重为: 0.710011, 偏置为: 0.781829
# 第275次优化的参数权重为: 0.709706, 偏置为: 0.781914
# 第276次优化的参数权重为: 0.709409, 偏置为: 0.782052
# 第277次优化的参数权重为: 0.709493, 偏置为: 0.782390
# 第278次优化的参数权重为: 0.709311, 偏置为: 0.782537
# 第279次优化的参数权重为: 0.709226, 偏置为: 0.782794
# 第280次优化的参数权重为: 0.709196, 偏置为: 0.783032
# 第281次优化的参数权重为: 0.708956, 偏置为: 0.783163
# 第282次优化的参数权重为: 0.709036, 偏置为: 0.783443
# 第283次优化的参数权重为: 0.708964, 偏置为: 0.783678
# 第284次优化的参数权重为: 0.708560, 偏置为: 0.783731
# 第285次优化的参数权重为: 0.708486, 偏置为: 0.783902
# 第286次优化的参数权重为: 0.708403, 偏置为: 0.784035
# 第287次优化的参数权重为: 0.708284, 偏置为: 0.784179
# 第288次优化的参数权重为: 0.708506, 偏置为: 0.784485
# 第289次优化的参数权重为: 0.708410, 偏置为: 0.784703
# 第290次优化的参数权重为: 0.707967, 偏置为: 0.784725
# 第291次优化的参数权重为: 0.707931, 偏置为: 0.784932
# 第292次优化的参数权重为: 0.707865, 偏置为: 0.785169
# 第293次优化的参数权重为: 0.707956, 偏置为: 0.785437
# 第294次优化的参数权重为: 0.707840, 偏置为: 0.785620
# 第295次优化的参数权重为: 0.707730, 偏置为: 0.785759
# 第296次优化的参数权重为: 0.707661, 偏置为: 0.785958
# 第297次优化的参数权重为: 0.707748, 偏置为: 0.786258
# 第298次优化的参数权重为: 0.707489, 偏置为: 0.786364
# 第299次优化的参数权重为: 0.707160, 偏置为: 0.786360
# 第300次优化的参数权重为: 0.707026, 偏置为: 0.786514
# 第301次优化的参数权重为: 0.707123, 偏置为: 0.786752
# 第302次优化的参数权重为: 0.707165, 偏置为: 0.786926
# 第303次优化的参数权重为: 0.707086, 偏置为: 0.787111
# 第304次优化的参数权重为: 0.706872, 偏置为: 0.787211
# 第305次优化的参数权重为: 0.706731, 偏置为: 0.787260
# 第306次优化的参数权重为: 0.706963, 偏置为: 0.787582
# 第307次优化的参数权重为: 0.706814, 偏置为: 0.787661
# 第308次优化的参数权重为: 0.706722, 偏置为: 0.787782
# 第309次优化的参数权重为: 0.706513, 偏置为: 0.787852
# 第310次优化的参数权重为: 0.706343, 偏置为: 0.787933
# 第311次优化的参数权重为: 0.706238, 偏置为: 0.788042
# 第312次优化的参数权重为: 0.706336, 偏置为: 0.788287
# 第313次优化的参数权重为: 0.706158, 偏置为: 0.788354
# 第314次优化的参数权重为: 0.706172, 偏置为: 0.788527
# 第315次优化的参数权重为: 0.706153, 偏置为: 0.788716
# 第316次优化的参数权重为: 0.706093, 偏置为: 0.788835
# 第317次优化的参数权重为: 0.705899, 偏置为: 0.788926
# 第318次优化的参数权重为: 0.705700, 偏置为: 0.788977
# 第319次优化的参数权重为: 0.705898, 偏置为: 0.789248
# 第320次优化的参数权重为: 0.705801, 偏置为: 0.789367
# 第321次优化的参数权重为: 0.705711, 偏置为: 0.789487
# 第322次优化的参数权重为: 0.705548, 偏置为: 0.789511
# 第323次优化的参数权重为: 0.705536, 偏置为: 0.789675
# 第324次优化的参数权重为: 0.705501, 偏置为: 0.789824
# 第325次优化的参数权重为: 0.705334, 偏置为: 0.789883
# 第326次优化的参数权重为: 0.705339, 偏置为: 0.790064
# 第327次优化的参数权重为: 0.705173, 偏置为: 0.790149
# 第328次优化的参数权重为: 0.705109, 偏置为: 0.790258
# 第329次优化的参数权重为: 0.705041, 偏置为: 0.790389
# 第330次优化的参数权重为: 0.705152, 偏置为: 0.790607
# 第331次优化的参数权重为: 0.705043, 偏置为: 0.790719
# 第332次优化的参数权重为: 0.705055, 偏置为: 0.790846
# 第333次优化的参数权重为: 0.704814, 偏置为: 0.790833
# 第334次优化的参数权重为: 0.704802, 偏置为: 0.790969
# 第335次优化的参数权重为: 0.704679, 偏置为: 0.791026
# 第336次优化的参数权重为: 0.704790, 偏置为: 0.791223
# 第337次优化的参数权重为: 0.704757, 偏置为: 0.791331
# 第338次优化的参数权重为: 0.704788, 偏置为: 0.791498
# 第339次优化的参数权重为: 0.704605, 偏置为: 0.791516
# 第340次优化的参数权重为: 0.704549, 偏置为: 0.791622
# 第341次优化的参数权重为: 0.704370, 偏置为: 0.791649
# 第342次优化的参数权重为: 0.704426, 偏置为: 0.791778
# 第343次优化的参数权重为: 0.704422, 偏置为: 0.791891
# 第344次优化的参数权重为: 0.704264, 偏置为: 0.791972
# 第345次优化的参数权重为: 0.704132, 偏置为: 0.792017
# 第346次优化的参数权重为: 0.704191, 偏置为: 0.792161
# 第347次优化的参数权重为: 0.704105, 偏置为: 0.792247
# 第348次优化的参数权重为: 0.704082, 偏置为: 0.792349
# 第349次优化的参数权重为: 0.704061, 偏置为: 0.792438
# 第350次优化的参数权重为: 0.704069, 偏置为: 0.792564
# 第351次优化的参数权重为: 0.703974, 偏置为: 0.792636
# 第352次优化的参数权重为: 0.703862, 偏置为: 0.792714
# 第353次优化的参数权重为: 0.703759, 偏置为: 0.792760
# 第354次优化的参数权重为: 0.703791, 偏置为: 0.792888
# 第355次优化的参数权重为: 0.703760, 偏置为: 0.792956
# 第356次优化的参数权重为: 0.703652, 偏置为: 0.793014
# 第357次优化的参数权重为: 0.703597, 偏置为: 0.793078
# 第358次优化的参数权重为: 0.703672, 偏置为: 0.793225
# 第359次优化的参数权重为: 0.703588, 偏置为: 0.793267
# 第360次优化的参数权重为: 0.703592, 偏置为: 0.793373
# 第361次优化的参数权重为: 0.703569, 偏置为: 0.793469
# 第362次优化的参数权重为: 0.703504, 偏置为: 0.793506
# 第363次优化的参数权重为: 0.703442, 偏置为: 0.793571
# 第364次优化的参数权重为: 0.703462, 偏置为: 0.793671
# 第365次优化的参数权重为: 0.703362, 偏置为: 0.793730
# 第366次优化的参数权重为: 0.703306, 偏置为: 0.793812
# 第367次优化的参数权重为: 0.703290, 偏置为: 0.793907
# 第368次优化的参数权重为: 0.703220, 偏置为: 0.793984
# 第369次优化的参数权重为: 0.703189, 偏置为: 0.794072
# 第370次优化的参数权重为: 0.703061, 偏置为: 0.794095
# 第371次优化的参数权重为: 0.703088, 偏置为: 0.794211
# 第372次优化的参数权重为: 0.703028, 偏置为: 0.794259
# 第373次优化的参数权重为: 0.703014, 偏置为: 0.794345
# 第374次优化的参数权重为: 0.703002, 偏置为: 0.794421
# 第375次优化的参数权重为: 0.702941, 偏置为: 0.794472
# 第376次优化的参数权重为: 0.702926, 偏置为: 0.794532
# 第377次优化的参数权重为: 0.702903, 偏置为: 0.794591
# 第378次优化的参数权重为: 0.702750, 偏置为: 0.794599
# 第379次优化的参数权重为: 0.702811, 偏置为: 0.794717
# 第380次优化的参数权重为: 0.702801, 偏置为: 0.794789
# 第381次优化的参数权重为: 0.702742, 偏置为: 0.794839
# 第382次优化的参数权重为: 0.702633, 偏置为: 0.794864
# 第383次优化的参数权重为: 0.702658, 偏置为: 0.794971
# 第384次优化的参数权重为: 0.702684, 偏置为: 0.795064
# 第385次优化的参数权重为: 0.702542, 偏置为: 0.795059
# 第386次优化的参数权重为: 0.702623, 偏置为: 0.795182
# 第387次优化的参数权重为: 0.702609, 偏置为: 0.795247
# 第388次优化的参数权重为: 0.702575, 偏置为: 0.795295
# 第389次优化的参数权重为: 0.702509, 偏置为: 0.795328
# 第390次优化的参数权重为: 0.702448, 偏置为: 0.795358
# 第391次优化的参数权重为: 0.702519, 偏置为: 0.795447
# 第392次优化的参数权重为: 0.702480, 偏置为: 0.795477
# 第393次优化的参数权重为: 0.702388, 偏置为: 0.795505
# 第394次优化的参数权重为: 0.702411, 偏置为: 0.795589
# 第395次优化的参数权重为: 0.702356, 偏置为: 0.795636
# 第396次优化的参数权重为: 0.702260, 偏置为: 0.795663
# 第397次优化的参数权重为: 0.702270, 偏置为: 0.795728
# 第398次优化的参数权重为: 0.702289, 偏置为: 0.795779
# 第399次优化的参数权重为: 0.702281, 偏置为: 0.795838
# 第400次优化的参数权重为: 0.702259, 偏置为: 0.795904
# 第401次优化的参数权重为: 0.702257, 偏置为: 0.795956
# 第402次优化的参数权重为: 0.702175, 偏置为: 0.795966
# 第403次优化的参数权重为: 0.702133, 偏置为: 0.795996
# 第404次优化的参数权重为: 0.702160, 偏置为: 0.796073
# 第405次优化的参数权重为: 0.702120, 偏置为: 0.796096
# 第406次优化的参数权重为: 0.702127, 偏置为: 0.796158
# 第407次优化的参数权重为: 0.701965, 偏置为: 0.796128
# 第408次优化的参数权重为: 0.702028, 偏置为: 0.796205
# 第409次优化的参数权重为: 0.701956, 偏置为: 0.796222
# 第410次优化的参数权重为: 0.702022, 偏置为: 0.796317
# 第411次优化的参数权重为: 0.702094, 偏置为: 0.796407
# 第412次优化的参数权重为: 0.701992, 偏置为: 0.796406
# 第413次优化的参数权重为: 0.701927, 偏置为: 0.796430
# 第414次优化的参数权重为: 0.701873, 偏置为: 0.796450
# 第415次优化的参数权重为: 0.701857, 偏置为: 0.796509
# 第416次优化的参数权重为: 0.701917, 偏置为: 0.796601
# 第417次优化的参数权重为: 0.701867, 偏置为: 0.796622
# 第418次优化的参数权重为: 0.701815, 偏置为: 0.796650
# 第419次优化的参数权重为: 0.701788, 偏置为: 0.796688
# 第420次优化的参数权重为: 0.701764, 偏置为: 0.796726
# 第421次优化的参数权重为: 0.701741, 偏置为: 0.796778
# 第422次优化的参数权重为: 0.701726, 偏置为: 0.796828
# 第423次优化的参数权重为: 0.701721, 偏置为: 0.796868
# 第424次优化的参数权重为: 0.701650, 偏置为: 0.796876
# 第425次优化的参数权重为: 0.701600, 偏置为: 0.796897
# 第426次优化的参数权重为: 0.701617, 偏置为: 0.796947
# 第427次优化的参数权重为: 0.701629, 偏置为: 0.797001
# 第428次优化的参数权重为: 0.701547, 偏置为: 0.797013
# 第429次优化的参数权重为: 0.701564, 偏置为: 0.797061
# 第430次优化的参数权重为: 0.701552, 偏置为: 0.797098
# 第431次优化的参数权重为: 0.701578, 偏置为: 0.797158
# 第432次优化的参数权重为: 0.701497, 偏置为: 0.797162
# 第433次优化的参数权重为: 0.701493, 偏置为: 0.797194
# 第434次优化的参数权重为: 0.701445, 偏置为: 0.797216
# 第435次优化的参数权重为: 0.701437, 偏置为: 0.797258
# 第436次优化的参数权重为: 0.701483, 偏置为: 0.797316
# 第437次优化的参数权重为: 0.701457, 偏置为: 0.797349
# 第438次优化的参数权重为: 0.701411, 偏置为: 0.797358
# 第439次优化的参数权重为: 0.701413, 偏置为: 0.797403
# 第440次优化的参数权重为: 0.701370, 偏置为: 0.797424
# 第441次优化的参数权重为: 0.701378, 偏置为: 0.797471
# 第442次优化的参数权重为: 0.701355, 偏置为: 0.797494
# 第443次优化的参数权重为: 0.701314, 偏置为: 0.797504
# 第444次优化的参数权重为: 0.701264, 偏置为: 0.797530
# 第445次优化的参数权重为: 0.701290, 偏置为: 0.797587
# 第446次优化的参数权重为: 0.701262, 偏置为: 0.797604
# 第447次优化的参数权重为: 0.701270, 偏置为: 0.797644
# 第448次优化的参数权重为: 0.701237, 偏置为: 0.797663
# 第449次优化的参数权重为: 0.701231, 偏置为: 0.797697
# 第450次优化的参数权重为: 0.701197, 偏置为: 0.797716
# 第451次优化的参数权重为: 0.701208, 偏置为: 0.797758
# 第452次优化的参数权重为: 0.701200, 偏置为: 0.797791
# 第453次优化的参数权重为: 0.701175, 偏置为: 0.797814
# 第454次优化的参数权重为: 0.701149, 偏置为: 0.797830
# 第455次优化的参数权重为: 0.701160, 偏置为: 0.797861
# 第456次优化的参数权重为: 0.701134, 偏置为: 0.797879
# 第457次优化的参数权重为: 0.701128, 偏置为: 0.797901
# 第458次优化的参数权重为: 0.701132, 偏置为: 0.797930
# 第459次优化的参数权重为: 0.701107, 偏置为: 0.797949
# 第460次优化的参数权重为: 0.701069, 偏置为: 0.797963
# 第461次优化的参数权重为: 0.701077, 偏置为: 0.797989
# 第462次优化的参数权重为: 0.701059, 偏置为: 0.798007
# 第463次优化的参数权重为: 0.701008, 偏置为: 0.798014
# 第464次优化的参数权重为: 0.701043, 偏置为: 0.798060
# 第465次优化的参数权重为: 0.700995, 偏置为: 0.798064
# 第466次优化的参数权重为: 0.701019, 偏置为: 0.798104
# 第467次优化的参数权重为: 0.701022, 偏置为: 0.798132
# 第468次优化的参数权重为: 0.701005, 偏置为: 0.798149
# 第469次优化的参数权重为: 0.700992, 偏置为: 0.798162
# 第470次优化的参数权重为: 0.700990, 偏置为: 0.798191
# 第471次优化的参数权重为: 0.700968, 偏置为: 0.798206
# 第472次优化的参数权重为: 0.700961, 偏置为: 0.798228
# 第473次优化的参数权重为: 0.700963, 偏置为: 0.798257
# 第474次优化的参数权重为: 0.700922, 偏置为: 0.798266
# 第475次优化的参数权重为: 0.700920, 偏置为: 0.798288
# 第476次优化的参数权重为: 0.700911, 偏置为: 0.798314
# 第477次优化的参数权重为: 0.700877, 偏置为: 0.798327
# 第478次优化的参数权重为: 0.700892, 偏置为: 0.798359
# 第479次优化的参数权重为: 0.700854, 偏置为: 0.798368
# 第480次优化的参数权重为: 0.700859, 偏置为: 0.798395
# 第481次优化的参数权重为: 0.700819, 偏置为: 0.798395
# 第482次优化的参数权重为: 0.700856, 偏置为: 0.798437
# 第483次优化的参数权重为: 0.700836, 偏置为: 0.798447
# 第484次优化的参数权重为: 0.700831, 偏置为: 0.798468
# 第485次优化的参数权重为: 0.700827, 偏置为: 0.798487
# 第486次优化的参数权重为: 0.700818, 偏置为: 0.798507
# 第487次优化的参数权重为: 0.700797, 偏置为: 0.798518
# 第488次优化的参数权重为: 0.700783, 偏置为: 0.798534
# 第489次优化的参数权重为: 0.700775, 偏置为: 0.798549
# 第490次优化的参数权重为: 0.700774, 偏置为: 0.798575
# 第491次优化的参数权重为: 0.700746, 偏置为: 0.798584
# 第492次优化的参数权重为: 0.700740, 偏置为: 0.798604
# 第493次优化的参数权重为: 0.700762, 偏置为: 0.798634
# 第494次优化的参数权重为: 0.700735, 偏置为: 0.798643
# 第495次优化的参数权重为: 0.700721, 偏置为: 0.798660
# 第496次优化的参数权重为: 0.700724, 偏置为: 0.798679
# 第497次优化的参数权重为: 0.700701, 偏置为: 0.798693
# 第498次优化的参数权重为: 0.700688, 偏置为: 0.798704
# 第499次优化的参数权重为: 0.700685, 偏置为: 0.798722
