# %%
import tensorflow as tf

def myregression():
    # 1、准备数据，x 特征值 [100, 1]   （100个样本，10个特征）
    x = tf.random_normal([100, 1], mean=1.75, stddev=0.5, name="x_data")
    y_true = tf.matmul(x, [[0.7]]) + 0.8

    # weight也是一个op
    weight = tf.Variable(tf.random_normal([1, 1], mean=0.0, stddev=1.0), name="weight")
    bias = tf.Variable(0.0, name="b")    # 初始化为0.0

    y_predict = tf.matmul(x, weight) + bias

    loss = tf.reduce_mean(tf.square(y_true - y_predict))

    train_op = tf.train.GradientDescentOptimizer(0.1).minimize(loss)

    initializer_op = tf.global_variables_initializer()  # 初始化变量weight和bias

    with tf.Session() as sess:
        sess.run(initializer_op)
        print("随机初始化的参数权重为: %f, 偏置为: %f" % (weight.eval(), bias.eval()))
       # 循环训练
        for i in range(400):
            sess.run(train_op)
            print("第%d次优化的参数权重为: %f, 偏置为: %f" % (i, weight.eval(), bias.eval()))

    return None

if __name__ == "__main__":
    myregression()
# Out:
# 随机初始化的参数权重为: 0.069434, 偏置为: 0.000000
# 第0次优化的参数权重为: 0.752214, 偏置为: 0.376152
# 第1次优化的参数权重为: 0.863384, 偏置为: 0.443125
# 第2次优化的参数权重为: 0.878118, 偏置为: 0.458305
# 第3次优化的参数权重为: 0.877043, 偏置为: 0.461881
# 第4次优化的参数权重为: 0.878915, 偏置为: 0.467412
# 第5次优化的参数权重为: 0.879210, 偏置为: 0.472187
# 第6次优化的参数权重为: 0.874673, 偏置为: 0.474849
# 第7次优化的参数权重为: 0.879617, 偏置为: 0.483166
# 第8次优化的参数权重为: 0.871305, 偏置为: 0.483895
# 第9次优化的参数权重为: 0.872567, 偏置为: 0.489346
# 第10次优化的参数权重为: 0.868548, 偏置为: 0.490056
# 第11次优化的参数权重为: 0.867380, 偏置为: 0.494477
# 第12次优化的参数权重为: 0.870485, 偏置为: 0.500317
# 第13次优化的参数权重为: 0.868846, 偏置为: 0.504058
# 第14次优化的参数权重为: 0.863780, 偏置为: 0.506412
# 第15次优化的参数权重为: 0.857047, 偏置为: 0.506973
# 第16次优化的参数权重为: 0.853169, 偏置为: 0.509616
# 第17次优化的参数权重为: 0.852653, 偏置为: 0.512930
# 第18次优化的参数权重为: 0.852290, 偏置为: 0.518127
# 第19次优化的参数权重为: 0.849679, 偏置为: 0.520450
# 第20次优化的参数权重为: 0.848221, 偏置为: 0.523718
# 第21次优化的参数权重为: 0.847202, 偏置为: 0.527159
# 第22次优化的参数权重为: 0.849298, 偏置为: 0.533303
# 第23次优化的参数权重为: 0.845078, 偏置为: 0.535114
# 第24次优化的参数权重为: 0.841671, 偏置为: 0.537818
# 第25次优化的参数权重为: 0.841964, 偏置为: 0.541354
# 第26次优化的参数权重为: 0.837231, 偏置为: 0.542192
# 第27次优化的参数权重为: 0.838601, 偏置为: 0.547294
# 第28次优化的参数权重为: 0.831698, 偏置为: 0.547006
# 第29次优化的参数权重为: 0.831793, 偏置为: 0.549983
# 第30次优化的参数权重为: 0.829371, 偏置为: 0.552868
# 第31次优化的参数权重为: 0.830227, 偏置为: 0.557944
# 第32次优化的参数权重为: 0.826288, 偏置为: 0.559155
# 第33次优化的参数权重为: 0.825177, 偏置为: 0.562656
# 第34次优化的参数权重为: 0.824771, 偏置为: 0.566139
# 第35次优化的参数权重为: 0.824763, 偏置为: 0.569853
# 第36次优化的参数权重为: 0.825456, 偏置为: 0.573716
# 第37次优化的参数权重为: 0.822571, 偏置为: 0.575191
# 第38次优化的参数权重为: 0.823962, 偏置为: 0.579110
# 第39次优化的参数权重为: 0.821309, 偏置为: 0.580825
# 第40次优化的参数权重为: 0.817575, 偏置为: 0.581315
# 第41次优化的参数权重为: 0.814027, 偏置为: 0.582614
# 第42次优化的参数权重为: 0.816646, 偏置为: 0.586877
# 第43次优化的参数权重为: 0.812156, 偏置为: 0.588069
# 第44次优化的参数权重为: 0.813800, 偏置为: 0.593342
# 第45次优化的参数权重为: 0.812247, 偏置为: 0.595649
# 第46次优化的参数权重为: 0.806703, 偏置为: 0.595471
# 第47次优化的参数权重为: 0.804728, 偏置为: 0.597785
# 第48次优化的参数权重为: 0.805960, 偏置为: 0.601673
# 第49次优化的参数权重为: 0.803045, 偏置为: 0.602894
# 第50次优化的参数权重为: 0.802890, 偏置为: 0.606077
# 第51次优化的参数权重为: 0.802417, 偏置为: 0.609318
# 第52次优化的参数权重为: 0.801818, 偏置为: 0.610756
# 第53次优化的参数权重为: 0.799974, 偏置为: 0.613682
# 第54次优化的参数权重为: 0.799618, 偏置为: 0.615894
# 第55次优化的参数权重为: 0.798909, 偏置为: 0.618412
# 第56次优化的参数权重为: 0.798001, 偏置为: 0.621352
# 第57次优化的参数权重为: 0.794130, 偏置为: 0.622314
# 第58次优化的参数权重为: 0.793402, 偏置为: 0.624561
# 第59次优化的参数权重为: 0.795897, 偏置为: 0.628734
# 第60次优化的参数权重为: 0.793314, 偏置为: 0.629918
# 第61次优化的参数权重为: 0.789448, 偏置为: 0.630647
# 第62次优化的参数权重为: 0.789070, 偏置为: 0.632903
# 第63次优化的参数权重为: 0.788643, 偏置为: 0.635387
# 第64次优化的参数权重为: 0.787311, 偏置为: 0.637165
# 第65次优化的参数权重为: 0.785574, 偏置为: 0.638407
# 第66次优化的参数权重为: 0.787547, 偏置为: 0.641758
# 第67次优化的参数权重为: 0.785548, 偏置为: 0.642972
# 第68次优化的参数权重为: 0.784406, 偏置为: 0.644586
# 第69次优化的参数权重为: 0.783259, 偏置为: 0.646483
# 第70次优化的参数权重为: 0.779767, 偏置为: 0.646702
# 第71次优化的参数权重为: 0.778941, 偏置为: 0.648153
# 第72次优化的参数权重为: 0.781185, 偏置为: 0.651970
# 第73次优化的参数权重为: 0.781456, 偏置为: 0.654531
# 第74次优化的参数权重为: 0.778567, 偏置为: 0.655675
# 第75次优化的参数权重为: 0.776008, 偏置为: 0.656518
# 第76次优化的参数权重为: 0.775792, 偏置为: 0.658536
# 第77次优化的参数权重为: 0.774864, 偏置为: 0.660090
# 第78次优化的参数权重为: 0.773375, 偏置为: 0.661151
# 第79次优化的参数权重为: 0.775325, 偏置为: 0.664728
# 第80次优化的参数权重为: 0.772010, 偏置为: 0.665814
# 第81次优化的参数权重为: 0.772466, 偏置为: 0.667970
# 第82次优化的参数权重为: 0.768867, 偏置为: 0.667692
# 第83次优化的参数权重为: 0.770266, 偏置为: 0.670145
# 第84次优化的参数权重为: 0.769663, 偏置为: 0.671716
# 第85次优化的参数权重为: 0.768123, 偏置为: 0.672899
# 第86次优化的参数权重为: 0.768407, 偏置为: 0.676214
# 第87次优化的参数权重为: 0.768450, 偏置为: 0.677919
# 第88次优化的参数权重为: 0.765351, 偏置为: 0.678481
# 第89次优化的参数权重为: 0.764556, 偏置为: 0.679451
# 第90次优化的参数权重为: 0.763281, 偏置为: 0.680719
# 第91次优化的参数权重为: 0.764009, 偏置为: 0.683516
# 第92次优化的参数权重为: 0.760827, 偏置为: 0.683496
# 第93次优化的参数权重为: 0.759467, 偏置为: 0.684607
# 第94次优化的参数权重为: 0.761419, 偏置为: 0.687508
# 第95次优化的参数权重为: 0.759630, 偏置为: 0.688261
# 第96次优化的参数权重为: 0.759000, 偏置为: 0.689407
# 第97次优化的参数权重为: 0.759694, 偏置为: 0.691285
# 第98次优化的参数权重为: 0.757357, 偏置为: 0.691454
# 第99次优化的参数权重为: 0.756603, 偏置为: 0.692793
# 第100次优化的参数权重为: 0.755614, 偏置为: 0.694103
# 第101次优化的参数权重为: 0.756409, 偏置为: 0.695700
# 第102次优化的参数权重为: 0.756114, 偏置为: 0.697162
# 第103次优化的参数权重为: 0.754412, 偏置为: 0.698048
# 第104次优化的参数权重为: 0.754423, 偏置为: 0.699773
# 第105次优化的参数权重为: 0.754256, 偏置为: 0.701257
# 第106次优化的参数权重为: 0.752629, 偏置为: 0.701993
# 第107次优化的参数权重为: 0.753137, 偏置为: 0.703951
# 第108次优化的参数权重为: 0.750397, 偏置为: 0.703870
# 第109次优化的参数权重为: 0.752077, 偏置为: 0.706132
# 第110次优化的参数权重为: 0.750955, 偏置为: 0.706821
# 第111次优化的参数权重为: 0.749738, 偏置为: 0.707400
# 第112次优化的参数权重为: 0.749202, 偏置为: 0.708204
# 第113次优化的参数权重为: 0.748855, 偏置为: 0.709381
# 第114次优化的参数权重为: 0.748976, 偏置为: 0.710681
# 第115次优化的参数权重为: 0.747511, 偏置为: 0.711271
# 第116次优化的参数权重为: 0.746977, 偏置为: 0.711979
# 第117次优化的参数权重为: 0.746936, 偏置为: 0.713102
# 第118次优化的参数权重为: 0.745587, 偏置为: 0.714109
# 第119次优化的参数权重为: 0.744735, 偏置为: 0.715029
# 第120次优化的参数权重为: 0.744842, 偏置为: 0.716126
# 第121次优化的参数权重为: 0.746269, 偏置为: 0.718460
# 第122次优化的参数权重为: 0.744282, 偏置为: 0.718841
# 第123次优化的参数权重为: 0.744413, 偏置为: 0.720165
# 第124次优化的参数权重为: 0.742750, 偏置为: 0.720324
# 第125次优化的参数权重为: 0.740983, 偏置为: 0.720658
# 第126次优化的参数权重为: 0.740090, 偏置为: 0.721318
# 第127次优化的参数权重为: 0.741805, 偏置为: 0.723522
# 第128次优化的参数权重为: 0.740643, 偏置为: 0.724201
# 第129次优化的参数权重为: 0.740344, 偏置为: 0.725371
# 第130次优化的参数权重为: 0.738677, 偏置为: 0.725476
# 第131次优化的参数权重为: 0.739067, 偏置为: 0.726797
# 第132次优化的参数权重为: 0.738189, 偏置为: 0.727142
# 第133次优化的参数权重为: 0.738385, 偏置为: 0.728470
# 第134次优化的参数权重为: 0.736658, 偏置为: 0.728809
# 第135次优化的参数权重为: 0.736058, 偏置为: 0.729644
# 第136次优化的参数权重为: 0.737607, 偏置为: 0.731504
# 第137次优化的参数权重为: 0.737268, 偏置为: 0.732665
# 第138次优化的参数权重为: 0.735155, 偏置为: 0.732705
# 第139次优化的参数权重为: 0.735986, 偏置为: 0.733960
# 第140次优化的参数权重为: 0.734744, 偏置为: 0.734109
# 第141次优化的参数权重为: 0.734446, 偏置为: 0.735058
# 第142次优化的参数权重为: 0.733544, 偏置为: 0.735730
# 第143次优化的参数权重为: 0.733654, 偏置为: 0.736549
# 第144次优化的参数权重为: 0.733240, 偏置为: 0.737467
# 第145次优化的参数权重为: 0.732831, 偏置为: 0.738385
# 第146次优化的参数权重为: 0.732552, 偏置为: 0.739186
# 第147次优化的参数权重为: 0.732318, 偏置为: 0.739951
# 第148次优化的参数权重为: 0.731627, 偏置为: 0.740460
# 第149次优化的参数权重为: 0.731921, 偏置为: 0.741646
# 第150次优化的参数权重为: 0.731627, 偏置为: 0.742313
# 第151次优化的参数权重为: 0.731895, 偏置为: 0.743276
# 第152次优化的参数权重为: 0.729571, 偏置为: 0.743245
# 第153次优化的参数权重为: 0.729369, 偏置为: 0.743893
# 第154次优化的参数权重为: 0.729672, 偏置为: 0.744742
# 第155次优化的参数权重为: 0.729996, 偏置为: 0.745739
# 第156次优化的参数权重为: 0.730271, 偏置为: 0.746616
# 第157次优化的参数权重为: 0.727896, 偏置为: 0.746107
# 第158次优化的参数权重为: 0.728390, 偏置为: 0.747207
# 第159次优化的参数权重为: 0.728133, 偏置为: 0.747775
# 第160次优化的参数权重为: 0.727491, 偏置为: 0.748269
# 第161次优化的参数权重为: 0.727030, 偏置为: 0.749021
# 第162次优化的参数权重为: 0.727330, 偏置为: 0.750030
# 第163次优化的参数权重为: 0.726897, 偏置为: 0.750581
# 第164次优化的参数权重为: 0.726653, 偏置为: 0.750983
# 第165次优化的参数权重为: 0.725769, 偏置为: 0.751240
# 第166次优化的参数权重为: 0.725444, 偏置为: 0.751821
# 第167次优化的参数权重为: 0.724724, 偏置为: 0.752054
# 第168次优化的参数权重为: 0.725357, 偏置为: 0.753029
# 第169次优化的参数权重为: 0.725246, 偏置为: 0.753671
# 第170次优化的参数权重为: 0.725245, 偏置为: 0.754271
# 第171次优化的参数权重为: 0.724818, 偏置为: 0.754781
# 第172次优化的参数权重为: 0.724287, 偏置为: 0.755225
# 第173次优化的参数权重为: 0.723917, 偏置为: 0.755903
# 第174次优化的参数权重为: 0.724254, 偏置为: 0.756748
# 第175次优化的参数权重为: 0.722409, 偏置为: 0.756353
# 第176次优化的参数权重为: 0.722636, 偏置为: 0.757080
# 第177次优化的参数权重为: 0.722589, 偏置为: 0.757632
# 第178次优化的参数权重为: 0.722150, 偏置为: 0.758103
# 第179次优化的参数权重为: 0.722341, 偏置为: 0.758782
# 第180次优化的参数权重为: 0.721714, 偏置为: 0.759142
# 第181次优化的参数权重为: 0.721987, 偏置为: 0.759804
# 第182次优化的参数权重为: 0.721465, 偏置为: 0.760239
# 第183次优化的参数权重为: 0.721703, 偏置为: 0.760976
# 第184次优化的参数权重为: 0.720543, 偏置为: 0.760953
# 第185次优化的参数权重为: 0.720799, 偏置为: 0.761677
# 第186次优化的参数权重为: 0.720086, 偏置为: 0.761982
# 第187次优化的参数权重为: 0.719922, 偏置为: 0.762381
# 第188次优化的参数权重为: 0.719762, 偏置为: 0.762776
# 第189次优化的参数权重为: 0.719764, 偏置为: 0.763292
# 第190次优化的参数权重为: 0.719820, 偏置为: 0.763864
# 第191次优化的参数权重为: 0.719567, 偏置为: 0.764283
# 第192次优化的参数权重为: 0.718938, 偏置为: 0.764471
# 第193次优化的参数权重为: 0.718839, 偏置为: 0.764912
# 第194次优化的参数权重为: 0.719278, 偏置为: 0.765628
# 第195次优化的参数权重为: 0.718547, 偏置为: 0.765836
# 第196次优化的参数权重为: 0.717557, 偏置为: 0.765696
# 第197次优化的参数权重为: 0.718006, 偏置为: 0.766520
# 第198次优化的参数权重为: 0.717379, 偏置为: 0.766711
# 第199次优化的参数权重为: 0.717590, 偏置为: 0.767312
# 第200次优化的参数权重为: 0.717627, 偏置为: 0.767764
# 第201次优化的参数权重为: 0.717184, 偏置为: 0.767984
# 第202次优化的参数权重为: 0.717310, 偏置为: 0.768509
# 第203次优化的参数权重为: 0.717452, 偏置为: 0.769061
# 第204次优化的参数权重为: 0.716602, 偏置为: 0.769045
# 第205次优化的参数权重为: 0.716911, 偏置为: 0.769660
# 第206次优化的参数权重为: 0.715128, 偏置为: 0.769250
# 第207次优化的参数权重为: 0.716381, 偏置为: 0.770380
# 第208次优化的参数权重为: 0.715488, 偏置为: 0.770335
# 第209次优化的参数权重为: 0.715425, 偏置为: 0.770775
# 第210次优化的参数权重为: 0.715379, 偏置为: 0.771201
# 第211次优化的参数权重为: 0.715246, 偏置为: 0.771624
# 第212次优化的参数权重为: 0.715198, 偏置为: 0.772027
# 第213次优化的参数权重为: 0.714667, 偏置为: 0.772100
# 第214次优化的参数权重为: 0.714810, 偏置为: 0.772608
# 第215次优化的参数权重为: 0.714474, 偏置为: 0.772870
# 第216次优化的参数权重为: 0.714238, 偏置为: 0.773119
# 第217次优化的参数权重为: 0.713955, 偏置为: 0.773325
# 第218次优化的参数权重为: 0.713685, 偏置为: 0.773600
# 第219次优化的参数权重为: 0.713806, 偏置为: 0.774084
# 第220次优化的参数权重为: 0.713430, 偏置为: 0.774255
# 第221次优化的参数权重为: 0.713422, 偏置为: 0.774717
# 第222次优化的参数权重为: 0.713969, 偏置为: 0.775357
# 第223次优化的参数权重为: 0.713545, 偏置为: 0.775462
# 第224次优化的参数权重为: 0.713429, 偏置为: 0.775781
# 第225次优化的参数权重为: 0.712603, 偏置为: 0.775724
# 第226次优化的参数权重为: 0.712512, 偏置为: 0.776103
# 第227次优化的参数权重为: 0.712875, 偏置为: 0.776733
# 第228次优化的参数权重为: 0.712382, 偏置为: 0.776787
# 第229次优化的参数权重为: 0.712333, 偏置为: 0.777249
# 第230次优化的参数权重为: 0.711967, 偏置为: 0.777393
# 第231次优化的参数权重为: 0.711880, 偏置为: 0.777803
# 第232次优化的参数权重为: 0.711779, 偏置为: 0.778114
# 第233次优化的参数权重为: 0.711785, 偏置为: 0.778473
# 第234次优化的参数权重为: 0.711192, 偏置为: 0.778478
# 第235次优化的参数权重为: 0.711507, 偏置为: 0.778974
# 第236次优化的参数权重为: 0.711594, 偏置为: 0.779303
# 第237次优化的参数权重为: 0.711244, 偏置为: 0.779469
# 第238次优化的参数权重为: 0.710780, 偏置为: 0.779521
# 第239次优化的参数权重为: 0.711068, 偏置为: 0.780021
# 第240次优化的参数权重为: 0.710863, 偏置为: 0.780183
# 第241次优化的参数权重为: 0.710471, 偏置为: 0.780269
# 第242次优化的参数权重为: 0.710520, 偏置为: 0.780547
# 第243次优化的参数权重为: 0.710743, 偏置为: 0.781015
# 第244次优化的参数权重为: 0.710430, 偏置为: 0.781094
# 第245次优化的参数权重为: 0.710412, 偏置为: 0.781315
# 第246次优化的参数权重为: 0.710123, 偏置为: 0.781413
# 第247次优化的参数权重为: 0.709975, 偏置为: 0.781631
# 第248次优化的参数权重为: 0.710061, 偏置为: 0.781996
# 第249次优化的参数权重为: 0.709732, 偏置为: 0.782122
# 第250次优化的参数权重为: 0.709487, 偏置为: 0.782247
# 第251次优化的参数权重为: 0.709563, 偏置为: 0.782503
# 第252次优化的参数权重为: 0.709052, 偏置为: 0.782523
# 第253次优化的参数权重为: 0.708978, 偏置为: 0.782809
# 第254次优化的参数权重为: 0.708765, 偏置为: 0.782929
# 第255次优化的参数权重为: 0.708991, 偏置为: 0.783338
# 第256次优化的参数权重为: 0.708806, 偏置为: 0.783518
# 第257次优化的参数权重为: 0.708983, 偏置为: 0.783794
# 第258次优化的参数权重为: 0.708461, 偏置为: 0.783730
# 第259次优化的参数权重为: 0.708609, 偏置为: 0.784060
# 第260次优化的参数权重为: 0.708744, 偏置为: 0.784413
# 第261次优化的参数权重为: 0.708373, 偏置为: 0.784448
# 第262次优化的参数权重为: 0.708201, 偏置为: 0.784570
# 第263次优化的参数权重为: 0.708191, 偏置为: 0.784834
# 第264次优化的参数权重为: 0.708218, 偏置为: 0.785102
# 第265次优化的参数权重为: 0.707660, 偏置为: 0.785070
# 第266次优化的参数权重为: 0.708066, 偏置为: 0.785507
# 第267次优化的参数权重为: 0.707793, 偏置为: 0.785556
# 第268次优化的参数权重为: 0.707680, 偏置为: 0.785691
# 第269次优化的参数权重为: 0.707591, 偏置为: 0.785805
# 第270次优化的参数权重为: 0.707571, 偏置为: 0.785984
# 第271次优化的参数权重为: 0.707486, 偏置为: 0.786252
# 第272次优化的参数权重为: 0.707309, 偏置为: 0.786355
# 第273次优化的参数权重为: 0.707246, 偏置为: 0.786582
# 第274次优化的参数权重为: 0.707202, 偏置为: 0.786733
# 第275次优化的参数权重为: 0.707201, 偏置为: 0.786926
# 第276次优化的参数权重为: 0.707032, 偏置为: 0.787021
# 第277次优化的参数权重为: 0.706676, 偏置为: 0.787062
# 第278次优化的参数权重为: 0.706870, 偏置为: 0.787337
# 第279次优化的参数权重为: 0.706751, 偏置为: 0.787503
# 第280次优化的参数权重为: 0.706352, 偏置为: 0.787489
# 第281次优化的参数权重为: 0.706421, 偏置为: 0.787721
# 第282次优化的参数权重为: 0.706634, 偏置为: 0.788040
# 第283次优化的参数权重为: 0.706337, 偏置为: 0.788084
# 第284次优化的参数权重为: 0.706498, 偏置为: 0.788341
# 第285次优化的参数权重为: 0.706398, 偏置为: 0.788416
# 第286次优化的参数权重为: 0.706341, 偏置为: 0.788595
# 第287次优化的参数权重为: 0.706097, 偏置为: 0.788624
# 第288次优化的参数权重为: 0.706131, 偏置为: 0.788857
# 第289次优化的参数权重为: 0.706114, 偏置为: 0.789009
# 第290次优化的参数权重为: 0.705961, 偏置为: 0.789091
# 第291次优化的参数权重为: 0.706007, 偏置为: 0.789267
# 第292次优化的参数权重为: 0.705856, 偏置为: 0.789369
# 第293次优化的参数权重为: 0.705832, 偏置为: 0.789538
# 第294次优化的参数权重为: 0.705617, 偏置为: 0.789615
# 第295次优化的参数权重为: 0.705708, 偏置为: 0.789834
# 第296次优化的参数权重为: 0.705440, 偏置为: 0.789880
# 第297次优化的参数权重为: 0.705249, 偏置为: 0.789929
# 第298次优化的参数权重为: 0.705129, 偏置为: 0.790002
# 第299次优化的参数权重为: 0.705196, 偏置为: 0.790194
# 第300次优化的参数权重为: 0.705168, 偏置为: 0.790328
# 第301次优化的参数权重为: 0.705070, 偏置为: 0.790399
# 第302次优化的参数权重为: 0.705169, 偏置为: 0.790595
# 第303次优化的参数权重为: 0.705129, 偏置为: 0.790749
# 第304次优化的参数权重为: 0.705062, 偏置为: 0.790869
# 第305次优化的参数权重为: 0.704855, 偏置为: 0.790871
# 第306次优化的参数权重为: 0.704829, 偏置为: 0.791028
# 第307次优化的参数权重为: 0.704813, 偏置为: 0.791141
# 第308次优化的参数权重为: 0.704716, 偏置为: 0.791211
# 第309次优化的参数权重为: 0.704704, 偏置为: 0.791340
# 第310次优化的参数权重为: 0.704666, 偏置为: 0.791411
# 第311次优化的参数权重为: 0.704591, 偏置为: 0.791469
# 第312次优化的参数权重为: 0.704602, 偏置为: 0.791596
# 第313次优化的参数权重为: 0.704539, 偏置为: 0.791693
# 第314次优化的参数权重为: 0.704298, 偏置为: 0.791692
# 第315次优化的参数权重为: 0.704402, 偏置为: 0.791872
# 第316次优化的参数权重为: 0.704368, 偏置为: 0.791966
# 第317次优化的参数权重为: 0.704359, 偏置为: 0.792093
# 第318次优化的参数权重为: 0.704211, 偏置为: 0.792138
# 第319次优化的参数权重为: 0.704145, 偏置为: 0.792238
# 第320次优化的参数权重为: 0.704067, 偏置为: 0.792313
# 第321次优化的参数权重为: 0.704009, 偏置为: 0.792395
# 第322次优化的参数权重为: 0.704085, 偏置为: 0.792535
# 第323次优化的参数权重为: 0.703805, 偏置为: 0.792509
# 第324次优化的参数权重为: 0.703853, 偏置为: 0.792650
# 第325次优化的参数权重为: 0.703879, 偏置为: 0.792764
# 第326次优化的参数权重为: 0.703844, 偏置为: 0.792850
# 第327次优化的参数权重为: 0.703740, 偏置为: 0.792902
# 第328次优化的参数权重为: 0.703643, 偏置为: 0.792945
# 第329次优化的参数权重为: 0.703653, 偏置为: 0.793049
# 第330次优化的参数权重为: 0.703655, 偏置为: 0.793150
# 第331次优化的参数权重为: 0.703614, 偏置为: 0.793226
# 第332次优化的参数权重为: 0.703624, 偏置为: 0.793337
# 第333次优化的参数权重为: 0.703506, 偏置为: 0.793377
# 第334次优化的参数权重为: 0.703410, 偏置为: 0.793426
# 第335次优化的参数权重为: 0.703480, 偏置为: 0.793567
# 第336次优化的参数权重为: 0.703383, 偏置为: 0.793584
# 第337次优化的参数权重为: 0.703443, 偏置为: 0.793733
# 第338次优化的参数权重为: 0.703296, 偏置为: 0.793730
# 第339次优化的参数权重为: 0.703326, 偏置为: 0.793810
# 第340次优化的参数权重为: 0.703302, 偏置为: 0.793878
# 第341次优化的参数权重为: 0.703257, 偏置为: 0.793934
# 第342次优化的参数权重为: 0.703222, 偏置为: 0.793998
# 第343次优化的参数权重为: 0.703131, 偏置为: 0.794046
# 第344次优化的参数权重为: 0.703137, 偏置为: 0.794143
# 第345次优化的参数权重为: 0.703094, 偏置为: 0.794216
# 第346次优化的参数权重为: 0.703154, 偏置为: 0.794336
# 第347次优化的参数权重为: 0.702991, 偏置为: 0.794323
# 第348次优化的参数权重为: 0.703016, 偏置为: 0.794439
# 第349次优化的参数权重为: 0.702995, 偏置为: 0.794502
# 第350次优化的参数权重为: 0.702938, 偏置为: 0.794551
# 第351次优化的参数权重为: 0.702834, 偏置为: 0.794577
# 第352次优化的参数权重为: 0.702790, 偏置为: 0.794637
# 第353次优化的参数权重为: 0.702790, 偏置为: 0.794728
# 第354次优化的参数权重为: 0.702747, 偏置为: 0.794792
# 第355次优化的参数权重为: 0.702753, 偏置为: 0.794862
# 第356次优化的参数权重为: 0.702681, 偏置为: 0.794899
# 第357次优化的参数权重为: 0.702684, 偏置为: 0.794991
# 第358次优化的参数权重为: 0.702665, 偏置为: 0.795050
# 第359次优化的参数权重为: 0.702578, 偏置为: 0.795078
# 第360次优化的参数权重为: 0.702624, 偏置为: 0.795163
# 第361次优化的参数权重为: 0.702571, 偏置为: 0.795219
# 第362次优化的参数权重为: 0.702558, 偏置为: 0.795261
# 第363次优化的参数权重为: 0.702520, 偏置为: 0.795315
# 第364次优化的参数权重为: 0.702461, 偏置为: 0.795382
# 第365次优化的参数权重为: 0.702459, 偏置为: 0.795471
# 第366次优化的参数权重为: 0.702436, 偏置为: 0.795538
# 第367次优化的参数权重为: 0.702463, 偏置为: 0.795643
# 第368次优化的参数权重为: 0.702391, 偏置为: 0.795667
# 第369次优化的参数权重为: 0.702360, 偏置为: 0.795719
# 第370次优化的参数权重为: 0.702297, 偏置为: 0.795744
# 第371次优化的参数权重为: 0.702303, 偏置为: 0.795811
# 第372次优化的参数权重为: 0.702219, 偏置为: 0.795831
# 第373次优化的参数权重为: 0.702194, 偏置为: 0.795874
# 第374次优化的参数权重为: 0.702160, 偏置为: 0.795918
# 第375次优化的参数权重为: 0.702111, 偏置为: 0.795946
# 第376次优化的参数权重为: 0.702085, 偏置为: 0.796006
# 第377次优化的参数权重为: 0.702142, 偏置为: 0.796088
# 第378次优化的参数权重为: 0.702056, 偏置为: 0.796085
# 第379次优化的参数权重为: 0.702090, 偏置为: 0.796153
# 第380次优化的参数权重为: 0.702046, 偏置为: 0.796187
# 第381次优化的参数权重为: 0.702065, 偏置为: 0.796261
# 第382次优化的参数权重为: 0.702030, 偏置为: 0.796297
# 第383次优化的参数权重为: 0.701959, 偏置为: 0.796313
# 第384次优化的参数权重为: 0.701902, 偏置为: 0.796343
# 第385次优化的参数权重为: 0.701917, 偏置为: 0.796414
# 第386次优化的参数权重为: 0.701937, 偏置为: 0.796495
# 第387次优化的参数权重为: 0.701893, 偏置为: 0.796517
# 第388次优化的参数权重为: 0.701861, 偏置为: 0.796542
# 第389次优化的参数权重为: 0.701843, 偏置为: 0.796593
# 第390次优化的参数权重为: 0.701801, 偏置为: 0.796615
# 第391次优化的参数权重为: 0.701783, 偏置为: 0.796662
# 第392次优化的参数权重为: 0.701749, 偏置为: 0.796692
# 第393次优化的参数权重为: 0.701740, 偏置为: 0.796741
# 第394次优化的参数权重为: 0.701670, 偏置为: 0.796753
# 第395次优化的参数权重为: 0.701686, 偏置为: 0.796808
# 第396次优化的参数权重为: 0.701677, 偏置为: 0.796857
# 第397次优化的参数权重为: 0.701658, 偏置为: 0.796882
# 第398次优化的参数权重为: 0.701638, 偏置为: 0.796919
# 第399次优化的参数权重为: 0.701659, 偏置为: 0.796989
