# %%
import tensorflow as tf

def myregression():
    # 1、准备数据，x 特征值 [100, 1]   （100个样本，10个特征）
    x = tf.random_normal([100, 1], mean=1.75, stddev=0.5, name="x_data")
    y_true = tf.matmul(x, [[0.7]]) + 0.8

    # weight也是一个op
    weight = tf.Variable(tf.random_normal([1, 1], mean=0.0, stddev=1.0), name="weight", trainable=False)
    bias = tf.Variable(0.0, name="b")    # 初始化为0.0

    y_predict = tf.matmul(x, weight) + bias

    loss = tf.reduce_mean(tf.square(y_true - y_predict))

    train_op = tf.train.GradientDescentOptimizer(0.1).minimize(loss)

    initializer_op = tf.global_variables_initializer()  # 初始化变量weight和bias

    with tf.Session() as sess:
        sess.run(initializer_op)
        print("随机初始化的参数权重为: %f, 偏置为: %f" % (weight.eval(), bias.eval()))
       # 循环训练
        for i in range(100):
            sess.run(train_op)
            print("第%d次优化的参数权重为: %f, 偏置为: %f" % (i, weight.eval(), bias.eval()))

    return None

if __name__ == "__main__":
    myregression()
# Out:
# 随机初始化的参数权重为: 2.285143, 偏置为: 0.000000
# 第0次优化的参数权重为: 2.285143, 偏置为: -0.399363
# 第1次优化的参数权重为: 2.285143, 偏置为: -0.696838
# 第2次优化的参数权重为: 2.285143, 偏置为: -0.996093
# 第3次优化的参数权重为: 2.285143, 偏置为: -1.182006
# 第4次优化的参数权重为: 2.285143, 偏置为: -1.345755
# 第5次优化的参数权重为: 2.285143, 偏置为: -1.456639
# 第6次优化的参数权重为: 2.285143, 偏置为: -1.567804
# 第7次优化的参数权重为: 2.285143, 偏置为: -1.650607
# 第8次优化的参数权重为: 2.285143, 偏置为: -1.703162
# 第9次优化的参数权重为: 2.285143, 偏置为: -1.772252
# 第10次优化的参数权重为: 2.285143, 偏置为: -1.858208
# 第11次优化的参数权重为: 2.285143, 偏置为: -1.906235
# 第12次优化的参数权重为: 2.285143, 偏置为: -1.893939
# 第13次优化的参数权重为: 2.285143, 偏置为: -1.911509
# 第14次优化的参数权重为: 2.285143, 偏置为: -1.945771
# 第15次优化的参数权重为: 2.285143, 偏置为: -1.947687
# 第16次优化的参数权重为: 2.285143, 偏置为: -1.958813
# 第17次优化的参数权重为: 2.285143, 偏置为: -1.955928
# 第18次优化的参数权重为: 2.285143, 偏置为: -1.952607
# 第19次优化的参数权重为: 2.285143, 偏置为: -1.939039
# 第20次优化的参数权重为: 2.285143, 偏置为: -1.918101
# 第21次优化的参数权重为: 2.285143, 偏置为: -1.914051
# 第22次优化的参数权重为: 2.285143, 偏置为: -1.962467
# 第23次优化的参数权重为: 2.285143, 偏置为: -1.965912
# 第24次优化的参数权重为: 2.285143, 偏置为: -1.954814
# 第25次优化的参数权重为: 2.285143, 偏置为: -1.977407
# 第26次优化的参数权重为: 2.285143, 偏置为: -1.986467
# 第27次优化的参数权重为: 2.285143, 偏置为: -1.993832
# 第28次优化的参数权重为: 2.285143, 偏置为: -1.987718
# 第29次优化的参数权重为: 2.285143, 偏置为: -2.005698
# 第30次优化的参数权重为: 2.285143, 偏置为: -2.003057
# 第31次优化的参数权重为: 2.285143, 偏置为: -1.999813
# 第32次优化的参数权重为: 2.285143, 偏置为: -1.984570
# 第33次优化的参数权重为: 2.285143, 偏置为: -2.004124
# 第34次优化的参数权重为: 2.285143, 偏置为: -1.986931
# 第35次优化的参数权重为: 2.285143, 偏置为: -2.021392
# 第36次优化的参数权重为: 2.285143, 偏置为: -2.009007
# 第37次优化的参数权重为: 2.285143, 偏置为: -2.000347
# 第38次优化的参数权重为: 2.285143, 偏置为: -2.015650
# 第39次优化的参数权重为: 2.285143, 偏置为: -2.018426
# 第40次优化的参数权重为: 2.285143, 偏置为: -2.013122
# 第41次优化的参数权重为: 2.285143, 偏置为: -2.016481
# 第42次优化的参数权重为: 2.285143, 偏置为: -2.015801
# 第43次优化的参数权重为: 2.285143, 偏置为: -1.985055
# 第44次优化的参数权重为: 2.285143, 偏置为: -1.973584
# 第45次优化的参数权重为: 2.285143, 偏置为: -1.966158
# 第46次优化的参数权重为: 2.285143, 偏置为: -1.943061
# 第47次优化的参数权重为: 2.285143, 偏置为: -1.961252
# 第48次优化的参数权重为: 2.285143, 偏置为: -1.957373
# 第49次优化的参数权重为: 2.285143, 偏置为: -1.954387
# 第50次优化的参数权重为: 2.285143, 偏置为: -1.965455
# 第51次优化的参数权重为: 2.285143, 偏置为: -1.963010
# 第52次优化的参数权重为: 2.285143, 偏置为: -1.965007
# 第53次优化的参数权重为: 2.285143, 偏置为: -1.972783
# 第54次优化的参数权重为: 2.285143, 偏置为: -1.980011
# 第55次优化的参数权重为: 2.285143, 偏置为: -1.952834
# 第56次优化的参数权重为: 2.285143, 偏置为: -1.965553
# 第57次优化的参数权重为: 2.285143, 偏置为: -1.977585
# 第58次优化的参数权重为: 2.285143, 偏置为: -1.980824
# 第59次优化的参数权重为: 2.285143, 偏置为: -2.013080
# 第60次优化的参数权重为: 2.285143, 偏置为: -2.032509
# 第61次优化的参数权重为: 2.285143, 偏置为: -2.001796
# 第62次优化的参数权重为: 2.285143, 偏置为: -2.016158
# 第63次优化的参数权重为: 2.285143, 偏置为: -2.017833
# 第64次优化的参数权重为: 2.285143, 偏置为: -2.014957
# 第65次优化的参数权重为: 2.285143, 偏置为: -2.005722
# 第66次优化的参数权重为: 2.285143, 偏置为: -2.001180
# 第67次优化的参数权重为: 2.285143, 偏置为: -1.990744
# 第68次优化的参数权重为: 2.285143, 偏置为: -2.023360
# 第69次优化的参数权重为: 2.285143, 偏置为: -2.006671
# 第70次优化的参数权重为: 2.285143, 偏置为: -2.020742
# 第71次优化的参数权重为: 2.285143, 偏置为: -2.025623
# 第72次优化的参数权重为: 2.285143, 偏置为: -2.032546
# 第73次优化的参数权重为: 2.285143, 偏置为: -2.009759
# 第74次优化的参数权重为: 2.285143, 偏置为: -2.032127
# 第75次优化的参数权重为: 2.285143, 偏置为: -2.029961
# 第76次优化的参数权重为: 2.285143, 偏置为: -2.003678
# 第77次优化的参数权重为: 2.285143, 偏置为: -2.004368
# 第78次优化的参数权重为: 2.285143, 偏置为: -1.987686
# 第79次优化的参数权重为: 2.285143, 偏置为: -1.975875
# 第80次优化的参数权重为: 2.285143, 偏置为: -1.992696
# 第81次优化的参数权重为: 2.285143, 偏置为: -1.961508
# 第82次优化的参数权重为: 2.285143, 偏置为: -1.976345
# 第83次优化的参数权重为: 2.285143, 偏置为: -1.998437
# 第84次优化的参数权重为: 2.285143, 偏置为: -2.002345
# 第85次优化的参数权重为: 2.285143, 偏置为: -2.027726
# 第86次优化的参数权重为: 2.285143, 偏置为: -2.007032
# 第87次优化的参数权重为: 2.285143, 偏置为: -2.005606
# 第88次优化的参数权重为: 2.285143, 偏置为: -2.027245
# 第89次优化的参数权重为: 2.285143, 偏置为: -2.002368
# 第90次优化的参数权重为: 2.285143, 偏置为: -1.988499
# 第91次优化的参数权重为: 2.285143, 偏置为: -1.996885
# 第92次优化的参数权重为: 2.285143, 偏置为: -1.988343
# 第93次优化的参数权重为: 2.285143, 偏置为: -1.989759
# 第94次优化的参数权重为: 2.285143, 偏置为: -1.944382
# 第95次优化的参数权重为: 2.285143, 偏置为: -1.968200
# 第96次优化的参数权重为: 2.285143, 偏置为: -1.958521
# 第97次优化的参数权重为: 2.285143, 偏置为: -1.986923
# 第98次优化的参数权重为: 2.285143, 偏置为: -1.963540
# 第99次优化的参数权重为: 2.285143, 偏置为: -1.969003
