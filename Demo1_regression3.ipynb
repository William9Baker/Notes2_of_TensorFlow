# %%
import tensorflow as tf

def myregression():
    # 1、准备数据，x 特征值 [100, 1]   （100个样本，1个特征）
    x = tf.random_normal([100, 1], mean=1.75, stddev=0.5, name="x_data")
    y_true = tf.matmul(x, [[0.7]]) + 0.8

    # weight也是一个op
    weight = tf.Variable(tf.random_normal([1, 1], mean=0.0, stddev=1.0), name="weight", trainable=False)
    bias = tf.Variable(0.0, name="b")    # 初始化为0.0

    y_predict = tf.matmul(x, weight) + bias

    loss = tf.reduce_mean(tf.square(y_true - y_predict))

    train_op = tf.train.GradientDescentOptimizer(0.1).minimize(loss)

    initializer_op = tf.global_variables_initializer()  # 初始化变量weight和bias

    with tf.Session() as sess:
        sess.run(initializer_op)
        print("随机初始化的参数权重为: %f, 偏置为: %f" % (weight.eval(), bias.eval()))
       # 循环训练
        for i in range(100):
            sess.run(train_op)
            print("第%d次优化的参数权重为: %f, 偏置为: %f" % (i, weight.eval(), bias.eval()))

    return None

if __name__ == "__main__":
    myregression()
# Out:
# 随机初始化的参数权重为: -0.909638, 偏置为: 0.000000
# 第0次优化的参数权重为: -0.909638, 偏置为: 0.741153
# 第1次优化的参数权重为: -0.909638, 偏置为: 1.319899
# 第2次优化的参数权重为: -0.909638, 偏置为: 1.774107
# 第3次优化的参数权重为: -0.909638, 偏置为: 2.152571
# 第4次优化的参数权重为: -0.909638, 偏置为: 2.457622
# 第5次优化的参数权重为: -0.909638, 偏置为: 2.682428
# 第6次优化的参数权重为: -0.909638, 偏置为: 2.890196
# 第7次优化的参数权重为: -0.909638, 偏置为: 3.020775
# 第8次优化的参数权重为: -0.909638, 偏置为: 3.117454
# 第9次优化的参数权重为: -0.909638, 偏置为: 3.252190
# 第10次优化的参数权重为: -0.909638, 偏置为: 3.312182
# 第11次优化的参数权重为: -0.909638, 偏置为: 3.346352
# 第12次优化的参数权重为: -0.909638, 偏置为: 3.415872
# 第13次优化的参数权重为: -0.909638, 偏置为: 3.461140
# 第14次优化的参数权重为: -0.909638, 偏置为: 3.469064
# 第15次优化的参数权重为: -0.909638, 偏置为: 3.498223
# 第16次优化的参数权重为: -0.909638, 偏置为: 3.546143
# 第17次优化的参数权重为: -0.909638, 偏置为: 3.550291
# 第18次优化的参数权重为: -0.909638, 偏置为: 3.574562
# 第19次优化的参数权重为: -0.909638, 偏置为: 3.567997
# 第20次优化的参数权重为: -0.909638, 偏置为: 3.551533
# 第21次优化的参数权重为: -0.909638, 偏置为: 3.566008
# 第22次优化的参数权重为: -0.909638, 偏置为: 3.572393
# 第23次优化的参数权重为: -0.909638, 偏置为: 3.561511
# 第24次优化的参数权重为: -0.909638, 偏置为: 3.561445
# 第25次优化的参数权重为: -0.909638, 偏置为: 3.554837
# 第26次优化的参数权重为: -0.909638, 偏置为: 3.566645
# 第27次优化的参数权重为: -0.909638, 偏置为: 3.568901
# 第28次优化的参数权重为: -0.909638, 偏置为: 3.572628
# 第29次优化的参数权重为: -0.909638, 偏置为: 3.610439
# 第30次优化的参数权重为: -0.909638, 偏置为: 3.623732
# 第31次优化的参数权重为: -0.909638, 偏置为: 3.630190
# 第32次优化的参数权重为: -0.909638, 偏置为: 3.633028
# 第33次优化的参数权重为: -0.909638, 偏置为: 3.632037
# 第34次优化的参数权重为: -0.909638, 偏置为: 3.627760
# 第35次优化的参数权重为: -0.909638, 偏置为: 3.618323
# 第36次优化的参数权重为: -0.909638, 偏置为: 3.610200
# 第37次优化的参数权重为: -0.909638, 偏置为: 3.612988
# 第38次优化的参数权重为: -0.909638, 偏置为: 3.613453
# 第39次优化的参数权重为: -0.909638, 偏置为: 3.636049
# 第40次优化的参数权重为: -0.909638, 偏置为: 3.649796
# 第41次优化的参数权重为: -0.909638, 偏置为: 3.662570
# 第42次优化的参数权重为: -0.909638, 偏置为: 3.663193
# 第43次优化的参数权重为: -0.909638, 偏置为: 3.651796
# 第44次优化的参数权重为: -0.909638, 偏置为: 3.657882
# 第45次优化的参数权重为: -0.909638, 偏置为: 3.671998
# 第46次优化的参数权重为: -0.909638, 偏置为: 3.660046
# 第47次优化的参数权重为: -0.909638, 偏置为: 3.656845
# 第48次优化的参数权重为: -0.909638, 偏置为: 3.653998
# 第49次优化的参数权重为: -0.909638, 偏置为: 3.633855
# 第50次优化的参数权重为: -0.909638, 偏置为: 3.644867
# 第51次优化的参数权重为: -0.909638, 偏置为: 3.646196
# 第52次优化的参数权重为: -0.909638, 偏置为: 3.613142
# 第53次优化的参数权重为: -0.909638, 偏置为: 3.585443
# 第54次优化的参数权重为: -0.909638, 偏置为: 3.580583
# 第55次优化的参数权重为: -0.909638, 偏置为: 3.607850
# 第56次优化的参数权重为: -0.909638, 偏置为: 3.602982
# 第57次优化的参数权重为: -0.909638, 偏置为: 3.584779
# 第58次优化的参数权重为: -0.909638, 偏置为: 3.593491
# 第59次优化的参数权重为: -0.909638, 偏置为: 3.599770
# 第60次优化的参数权重为: -0.909638, 偏置为: 3.606560
# 第61次优化的参数权重为: -0.909638, 偏置为: 3.635803
# 第62次优化的参数权重为: -0.909638, 偏置为: 3.647722
# 第63次优化的参数权重为: -0.909638, 偏置为: 3.643394
# 第64次优化的参数权重为: -0.909638, 偏置为: 3.620141
# 第65次优化的参数权重为: -0.909638, 偏置为: 3.609729
# 第66次优化的参数权重为: -0.909638, 偏置为: 3.620018
# 第67次优化的参数权重为: -0.909638, 偏置为: 3.614006
# 第68次优化的参数权重为: -0.909638, 偏置为: 3.626813
# 第69次优化的参数权重为: -0.909638, 偏置为: 3.623009
# 第70次优化的参数权重为: -0.909638, 偏置为: 3.605464
# 第71次优化的参数权重为: -0.909638, 偏置为: 3.606024
# 第72次优化的参数权重为: -0.909638, 偏置为: 3.602179
# 第73次优化的参数权重为: -0.909638, 偏置为: 3.606947
# 第74次优化的参数权重为: -0.909638, 偏置为: 3.604221
# 第75次优化的参数权重为: -0.909638, 偏置为: 3.576163
# 第76次优化的参数权重为: -0.909638, 偏置为: 3.591816
# 第77次优化的参数权重为: -0.909638, 偏置为: 3.614989
# 第78次优化的参数权重为: -0.909638, 偏置为: 3.619111
# 第79次优化的参数权重为: -0.909638, 偏置为: 3.629016
# 第80次优化的参数权重为: -0.909638, 偏置为: 3.600977
# 第81次优化的参数权重为: -0.909638, 偏置为: 3.593596
# 第82次优化的参数权重为: -0.909638, 偏置为: 3.599578
# 第83次优化的参数权重为: -0.909638, 偏置为: 3.597817
# 第84次优化的参数权重为: -0.909638, 偏置为: 3.610314
# 第85次优化的参数权重为: -0.909638, 偏置为: 3.609041
# 第86次优化的参数权重为: -0.909638, 偏置为: 3.626554
# 第87次优化的参数权重为: -0.909638, 偏置为: 3.629778
# 第88次优化的参数权重为: -0.909638, 偏置为: 3.615923
# 第89次优化的参数权重为: -0.909638, 偏置为: 3.620479
# 第90次优化的参数权重为: -0.909638, 偏置为: 3.622459
# 第91次优化的参数权重为: -0.909638, 偏置为: 3.635007
# 第92次优化的参数权重为: -0.909638, 偏置为: 3.618067
# 第93次优化的参数权重为: -0.909638, 偏置为: 3.624269
# 第94次优化的参数权重为: -0.909638, 偏置为: 3.626595
# 第95次优化的参数权重为: -0.909638, 偏置为: 3.618195
# 第96次优化的参数权重为: -0.909638, 偏置为: 3.619781
# 第97次优化的参数权重为: -0.909638, 偏置为: 3.626817
# 第98次优化的参数权重为: -0.909638, 偏置为: 3.620163
# 第99次优化的参数权重为: -0.909638, 偏置为: 3.603931
